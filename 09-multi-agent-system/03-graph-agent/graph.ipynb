# %% [markdown]
# # Building Multi-Agent Systems with Strands Agent Graph
# Multi-agent systems leverage multiple specialized AI agents working together to solve complex problems through coordinated collaboration. Each agent has specific capabilities and roles, connected through explicit communication pathways.
#
# In this lab, you'll learn to build multi-agent systems using the Strands Agent SDK. We'll progress from basic concepts to advanced implementations, exploring different topologies and real-world applications.
#
# **Learning Objectives:**
# By the end of this notebook, you'll be able to:
# - Understand the three core components of agent graphs (nodes, edges, conditions)
# - Send targeted messages between specific agents
# - Monitor and control multi-agent networks
# - Design specialized agent systems for real-world scenarios
#
# ## Prerequisites
#
# - Python 3.10+
# - AWS account with Anthropic Claude 3.7 enabled on Amazon Bedrock
# - IAM role with permissions to use Amazon Bedrock
# - Basic understanding of AI agents and prompt engineering

# %% [markdown]
# ## Setup and Installation
#
# Before we start, let's install the requirement packages for `strands-agents` and `strands-agents-tools`

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: strands-agents in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (1.18.0)
# Requirement already satisfied: strands-agents-tools in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (0.2.16)
# Requirement already satisfied: boto3<2.0.0,>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.41.5)
# Requirement already satisfied: botocore<2.0.0,>=1.29.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.41.5)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.17.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (4.25.1)
# Requirement already satisfied: mcp<2.0.0,>=1.11.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.22.0)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.38.0)
# Requirement already satisfied: opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.59b0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.38.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (2.12.5)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: s3transfer<0.16.0,>=0.15.0 in /opt/conda/lib/python3.12/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (0.15.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.12/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.12/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (0.29.0)
# Requirement already satisfied: anyio>=4.5 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (4.12.0)
# Requirement already satisfied: httpx-sse>=0.4 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (2.12.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /opt/conda/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: starlette>=0.27 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.49.3)
# Requirement already satisfied: typing-inspection>=0.4.1 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.38.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 1)) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 1)) (3.23.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.59b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.59b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (1.17.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.59b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.59b0)
# Requirement already satisfied: packaging>=18.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.59b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents->-r requirements.txt (line 1)) (2.41.5)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (3.13.2)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.3)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.0)
# Requirement already satisfied: markdownify<2.0.0,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.2.2)
# Requirement already satisfied: pillow<12.0.0,>=11.2.1 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (11.3.0)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.51 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (3.0.52)
# Requirement already satisfied: requests<3.0.0,>=2.28.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (2.32.5)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (14.2.0)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.25.0)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (9.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.22.0)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /opt/conda/lib/python3.12/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (4.14.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.12/site-packages (from beautifulsoup4<5,>=4.9->markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.8)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.12/site-packages (from prompt-toolkit<4.0.0,>=3.0.51->strands-agents-tools->-r requirements.txt (line 2)) (0.2.14)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (2025.11.12)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.12/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.12/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.19.2)
# Requirement already satisfied: slack_sdk<4,>=3.35.0 in /opt/conda/lib/python3.12/site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools->-r requirements.txt (line 2)) (3.37.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx>=0.27.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/conda/lib/python3.12/site-packages (from pydantic-settings>=2.5.2->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (1.2.1)
# Requirement already satisfied: cryptography>=3.4.0 in /opt/conda/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (2.23)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.12/site-packages (from uvicorn>=0.31.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (8.3.1)

# %% [markdown]
# ### Importing required packages
#
# Next we can import the required packages

# %%
from strands import Agent

# %% [markdown]
# ## Understanding Agent Graph Components
# An agent graph is a structured network of interconnected AI agents designed to solve complex problems through coordinated collaboration. Each agent represents a specialized node with specific capabilities, and the connections between agents define explicit communication pathways.
#
# Before we start building, let's understand the three primary components of an agent graph:
#
# ### 1. Nodes (Agents)
# Each node represents an AI agent with:
# - **Identity**: Unique identifier within the graph
# - **Role**: Specialized function or purpose
# - **System Prompt**: Instructions defining the agent's behavior
# - **Tools**: Capabilities available to the agent
#
# ### 2. Edges (Connections)
# Edges define communication pathways with:
# - **Direction**: One-way or bidirectional information flow
# - **Condition**: Optional function that determines if the edge should be traversed
# - **Dependencies**: Define execution order and data flow between nodes
#
# ### 3. GraphBuilder
# The GraphBuilder provides a simple interface for constructing graphs:
# - **add_node()**: Add an agent or multi-agent system as a node
# - **add_edge()**: Create a dependency between nodes
# - **set_entry_point()**: Define starting nodes for execution
# - **build()**: Validate and create the Graph instance

# %% [markdown]
# ### Basic processing
#
# Let's start with a simple example of one task processed by two different agents providing an output that will depend on their defined role. Take a look at the execution order of the nodes and also the fact that with STrands SDK you can explicitly get a response only from one single node if needed. Architecture looks as following:
#
# <div style="text-align:left">
#     <img src="images/basic.png" width="55%" />
# </div>

# %%
#Initialize an agent with agent_graph capability
from strands.multiagent import GraphBuilder

# Create specialized agents
coordinator = Agent(name="coordinator", system_prompt="You are a research team leader coordinating specialists. Provide a short analysis, no need for follow ups")
analyst = Agent(name="data_analyst", system_prompt="You are a data analyst specializing in statistical analysis. Provide a short analysis, no need for follow ups")
domain_expert = Agent(name="domain_expert", system_prompt="You are a domain expert with deep subject knowledge. Provide a short analysis, no need for follow ups")

# Build the graph
builder = GraphBuilder()

# Add nodes
builder.add_node(coordinator, "team_lead")
builder.add_node(analyst, "analyst")
builder.add_node(domain_expert, "expert")

# Add edges (dependencies)
builder.add_edge("team_lead", "analyst")
builder.add_edge("team_lead", "expert")

# Set entry points (optional - will be auto-detected if not specified)
builder.set_entry_point("team_lead")

# Build the graph
graph = builder.build()

#Execute task on newly built graph
result = graph("Analyze the impact of remote work on employee productivity.Provide a short analysis, no need for follow ups")
print("\n")
print("============================================================")
print("============================================================")

print(f"Response: {result}")

print("=============Node execution order:==========================")
print("============================================================")

# See which nodes were executed and in what order
for node in result.execution_order:
    print(f"Executed: {node.node_id}")

print("=============Graph metrics:=================================")
print("============================================================")


# Get performance metrics
print(f"Total nodes: {result.total_nodes}")
print(f"Completed nodes: {result.completed_nodes}")
print(f"Failed nodes: {result.failed_nodes}")
print(f"Execution time: {result.execution_time}ms")
print(f"Token usage: {result.accumulated_usage}")


# Get results from specific nodes
print("\n")
print("=============Expert node results only:======================")
print("============================================================")
print(result.results["expert"].result)
# Out:
# Graph without execution limits may run indefinitely if cycles exist
# # Remote Work Productivity Analysis
#
# ## Key Findings
#
# **Overall Impact**: Mixed but generally positive, with significant variation by role type and individual factors.
#
# ## Productivity Gains
# - **Elimination of commute**: 1-3 hours daily returned to productive use
# - **Reduced office distractions**: Fewer interruptions from meetings and social interactions
# - **Flexible scheduling**: Better alignment with individual peak performance hours
# - **Improved work-life integration**: Enhanced employee satisfaction and reduced burnout
#
# ## Productivity Challenges
# - **Communication overhead**: Increased time spent on video calls and written coordination
# - **Collaboration friction**: More difficult spontaneous problem-solving and knowledge transfer
# - **Home environment barriers**: Distractions, inadequate workspace, family responsibilities
# - **Technology limitations**: Connectivity issues and suboptimal home office setups
#
# ## Performance Variations by Role
# - **Individual contributors**: Generally maintain or improve productivity
# - **Creative/collaborative roles**: Often see decreased productivity due to reduced serendipitous interactions
# - **Management roles**: Mixed results depending on team management adaptation
#
# ## Measurable Outcomes
# Studies show productivity changes ranging from -10% to +20%, with most organizations reporting neutral to slightly positive impacts when proper infrastructure and management practices are implemented.
#
# ## Critical Success Factors
# Strong digital communication tools, clear performance metrics, manager training, and employee autonomy significantly influence positive outcomes.# Statistical Analysis: Remote Work Productivity Impact
#
# ## Data Summary
# Based on the team lead's findings, remote work productivity shows a **normal distribution with slight positive skew**, ranging from -10% to +20% change from baseline.
#
# ## Key Statistical Insights
#
# **Central Tendency:**
# - Mean productivity change: ~+3#-5% (slightly Remote Work Productivity Impact positive)
# - High Analysis
#
# ## Executive Summary
# Remote work demonstrates a **net positive impact** on productivity when properly implemented, though variance indicates individual and role-dependent factors drive outcomes more than the remote work factor alone
#
# **Correlation effects Patterns:**
# - ** vary significantly acrossStrong positive correlation** between productivity gains roles and organizational and:
#   - contexts.
#
# ## Core Comm Productivityute time eliminate Dynamicsd (r
#
# **Efficiency≈  Gains (0.6-0.7)Primary
#   - Individual contributor roles vs Drivers. collaborative):**
# - Time roles re
#   - Quality of home office setup
#
# **Varianceall Analysis:**
# - **ocation from commuting toRole type productive explains ~ work (40-average50% 54** of productivity variance
# - **Individual factors minutes daily)
# - Reduce (homed workplace environment, self interru-managementptions leading)** account to deeper for ~30-35%
# - ** focus periodsOrganizational support
# - Person systems** explainalized work ~15-20% environments
#
# ## Statistical Significance
# The wide optimized for individual performance range (-
# - Flexible10% to +20%) suggests scheduling aligne **d with natural productivityhigh standar rhythd deviation**ms
#
# **Productivity (σ ≈ Friction 8 Points-10%), indicating that while:**
# - Increased coordination the mean overhead through is positive, results are digital highly variable and context-dependent.
#
# ** channelsConfidence
# - Dimin Assessmentished informal:** knowledge Moderate statistical power transfer and ment due to confounding variables, but consistentoring direct
# - Technologyional trends across multiple studies increase an reliabilityd workspace of the limitations in slight home environments
# - positive bias finding Potential for work-life boundary.
#
# ** erosion affectingRecommendation long:** Focus metrics-term sustainability on role
#
# ## Role-specific cohorts rather than organization-Specific Impact-wide averages for Patterns more actionable insights.
#
# - **Knowledge workers**: Strongest positive correlation (+5-15% productivity gains)
# - **Creative/collaborative roles**: Variable outcomes, often requiring hybrid approaches
# - **Customer-facing positions**: Technology-dependent, with quality maintenance challenges
# - **Management functions**: Success tied directly to digital leadership adaptation
#
# ## Implementation Critical Path
# The productivity outcome is largely determined by:
# 1. **Infrastructure quality** (reliable technology, proper workspace)
# 2. **Management competency** in remote team leadership
# 3. **Communication framework** effectiveness
# 4. **Performance measurement** alignment with remote work realities
#
# **Bottom Line**: Organizations with intentional remote work strategies typically achieve 5-10% productivity improvements, while ad-hoc implementations often see neutral to slightly negative results.
#
# ============================================================
# ============================================================
# Response: GraphResult(status=<Status.COMPLETED: 'completed'>, results={'team_lead': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': '# Remote Work Productivity Analysis\n\n## Key Findings\n\n**Overall Impact**: Mixed but generally positive, with significant variation by role type and individual factors.\n\n## Productivity Gains\n- **Elimination of commute**: 1-3 hours daily returned to productive use\n- **Reduced office distractions**: Fewer interruptions from meetings and social interactions\n- **Flexible scheduling**: Better alignment with individual peak performance hours\n- **Improved work-life integration**: Enhanced employee satisfaction and reduced burnout\n\n## Productivity Challenges\n- **Communication overhead**: Increased time spent on video calls and written coordination\n- **Collaboration friction**: More difficult spontaneous problem-solving and knowledge transfer\n- **Home environment barriers**: Distractions, inadequate workspace, family responsibilities\n- **Technology limitations**: Connectivity issues and suboptimal home office setups\n\n## Performance Variations by Role\n- **Individual contributors**: Generally maintain or improve productivity\n- **Creative/collaborative roles**: Often see decreased productivity due to reduced serendipitous interactions\n- **Management roles**: Mixed results depending on team management adaptation\n\n## Measurable Outcomes\nStudies show productivity changes ranging from -10% to +20%, with most organizations reporting neutral to slightly positive impacts when proper infrastructure and management practices are implemented.\n\n## Critical Success Factors\nStrong digital communication tools, clear performance metrics, manager training, and employee autonomy significantly influence positive outcomes.'}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[4.432778596878052], traces=[<strands.telemetry.metrics.Trace object at 0x7f39d68df170>], accumulated_usage={'inputTokens': 50, 'outputTokens': 303, 'totalTokens': 353}, accumulated_metrics={'latencyMs': 4411}), state={}, interrupts=None, structured_output=None), execution_time=4433, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 50, 'outputTokens': 303, 'totalTokens': 353}, accumulated_metrics={'latencyMs': 4411}, execution_count=1), 'analyst': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': "# Statistical Analysis: Remote Work Productivity Impact\n\n## Data Summary\nBased on the team lead's findings, remote work productivity shows a **normal distribution with slight positive skew**, ranging from -10% to +20% change from baseline.\n\n## Key Statistical Insights\n\n**Central Tendency:**\n- Mean productivity change: ~+3-5% (slightly positive)\n- High variance indicates individual and role-dependent factors drive outcomes more than the remote work factor alone\n\n**Correlation Patterns:**\n- **Strong positive correlation** between productivity gains and:\n  - Commute time eliminated (r ≈ 0.6-0.7)\n  - Individual contributor roles vs. collaborative roles\n  - Quality of home office setup\n\n**Variance Analysis:**\n- **Role type explains ~40-50%** of productivity variance\n- **Individual factors (home environment, self-management)** account for ~30-35%\n- **Organizational support systems** explain ~15-20%\n\n## Statistical Significance\nThe wide range (-10% to +20%) suggests **high standard deviation** (σ ≈ 8-10%), indicating that while the mean is positive, results are highly variable and context-dependent.\n\n**Confidence Assessment:** Moderate statistical power due to confounding variables, but consistent directional trends across multiple studies increase reliability of the slight positive bias finding.\n\n**Recommendation:** Focus metrics on role-specific cohorts rather than organization-wide averages for more actionable insights."}]}, metrics=EventLoopMetrics(cycle_ ...
# =============Node execution order:==========================
# ============================================================
# Executed: team_lead
# Executed: analyst
# Executed: expert
# =============Graph metrics:=================================
# ============================================================
# Total nodes: 3
# Completed nodes: 3
# Failed nodes: 0
# Execution time: 0ms
# Token usage: {'inputTokens': 791, 'outputTokens': 964, 'totalTokens': 1755}
#
#
# =============Expert node results only:======================
# ============================================================
# # Remote Work Productivity Impact Analysis
#
# ## Executive Summary
# Remote work demonstrates a **net positive impact** on productivity when properly implemented, though effects vary significantly across roles and organizational contexts.
#
# ## Core Productivity Dynamics
#
# **Efficiency Gains (Primary Drivers):**
# - Time reallocation from commuting to productive work (average 54 minutes daily)
# - Reduced workplace interruptions leading to deeper focus periods
# - Personalized work environments optimized for individual performance
# - Flexible scheduling aligned with natural productivity rhythms
#
# **Productivity Friction Points:**
# - Increased coordination overhead through digital channels
# - Diminished informal knowledge transfer and mentoring
# - Technology and workspace limitations in home environments
# - Potential for work-life boundary erosion affecting long-term sustainability
#
# ## Role-Specific Impact Patterns
#
# - **Knowledge workers**: Strongest positive correlation (+5-15% productivity gains)
# - **Creative/collaborative roles**: Variable outcomes, often requiring hybrid approaches
# - **Customer-facing positions**: Technology-dependent, with quality maintenance challenges
# - **Management functions**: Success tied directly to digital leadership adaptation
#
# ## Implementation Critical Path
# The productivity outcome is largely determined by:
# 1. **Infrastructure quality** (reliable technology, proper workspace)
# 2. **Management competency** in remote team leadership
# 3. **Communication framework** effectiveness
# 4. **Performance measurement** alignment with remote work realities
#
# **Bottom Line**: Organizations with intentional remote work strategies typically achieve 5-10% productivity improvements, while ad-hoc implementations often see neutral to slightly negative results.

# %% [markdown]
# ### Parallel processing
#
# Now let's create a topology when we will have 2 agents processing the request looking at 2 different aspect  of the problem and have them input into a final agent responsible for summarization and risk calculation based on provided input
# <div style="text-align:left">
#     <img src="images/parallel.png" width="55%" />
# </div>

# %%
#Initialize an agent with agent_graph capability
from strands.multiagent import GraphBuilder

mesh_agent = Agent()
# Create specialized agents

financial_advisor = Agent(name="financial_advisor", system_prompt="You are a financial advisor focused on cost-benefit analysis, budget implications, and ROI calculations. Engage with other experts to build comprehensive financial perspectives.")
technical_architect = Agent(name="technical_architect", system_prompt="You are a technical architect who evaluates feasibility, implementation challenges, and technical risks. Collaborate with other experts to ensure technical viability.")
market_researcher = Agent(name="market_researcher", system_prompt="You are a market researcher who analyzes market conditions, user needs, and competitive landscape. Work with other experts to validate market opportunities.")
risk_analyst = Agent(name="risk_analyst", system_prompt="You are a risk analyst who identifies potential risks, mitigation strategies, and compliance issues. Collaborate with other experts to ensure comprehensive risk assessment.")


# Build the graph
builder = GraphBuilder()

# Add nodes
builder.add_node(financial_advisor, "finance_expert")
builder.add_node(technical_architect, "tech_expert")
builder.add_node(market_researcher, "market_expert")
builder.add_node(risk_analyst, "risk_analyst")

# Add edges (dependencies)
builder.add_edge("finance_expert", "tech_expert")  
builder.add_edge("finance_expert", "market_expert")  ## Parallels
builder.add_edge("tech_expert", "risk_analyst")
builder.add_edge("market_expert", "risk_analyst")


# Set entry points (optional - will be auto-detected if not specified)
builder.set_entry_point("finance_expert")

# Build the graph
graph = builder.build()

print("============================================================")
print("============================================================")

#Execute task on newly built graph
result = graph("Our company is considering launching a new AI-powered customer service platform. Initial investment is \$2M with projected 3-year ROI of 150%. What's your financial assessment?")
print("\n")
print("============================================================")
print("============================================================")

print(f"Response: {result}")

print("=============Node execution order:==========================")
print("============================================================")

# See which nodes were executed and in what order
for node in result.execution_order:
    print(f"Executed: {node.node_id}")

print("=============Graph metrics:=================================")
print("============================================================")


# Get performance metrics
print(f"Total nodes: {result.total_nodes}")
print(f"Completed nodes: {result.completed_nodes}")
print(f"Failed nodes: {result.failed_nodes}")
print(f"Execution time: {result.execution_time}ms")
print(f"Token usage: {result.accumulated_usage}")


# Get results from specific nodes

print("Financial Advisor:")
print("============================================================")
print("============================================================")
print(result.results["finance_expert"].result)
print("\n")

print("Technical Expert:")
print("============================================================")
print("============================================================")
print(result.results["tech_expert"].result)
print("\n")

print("Market Researcher:")
print("============================================================")
print("============================================================")
print(result.results["market_expert"].result)
print("\n")
# Out:
# Graph without execution limits may run indefinitely if cycles exist
# ============================================================
# ============================================================
# ## Financial Assessment: AI Customer Service Platform
#
# ### Initial ROI Analysis
# A 150% ROI over 3 years translates to:
# - **Total return**: $5M ($2M investment + $3M profit)
# - **Annualized ROI**: ~35.7%
# - **Break-even point**: Approximately 1.2-1.4 years
#
# This is **strong performance** compared to typical enterprise software investments (15-25% annual ROI).
#
# ### Key Financial Considerations I'd Explore:
#
# **Revenue Impact Drivers:**
# - Volume of customer interactions the AI will handle
# - Cost per interaction savings vs. current human agents
# - Potential revenue uplift from improved customer satisfaction/retention
# - Capacity to handle peak loads without additional hiring
#
# **Cost Structure Deep-Dive:**
# - Annual licensing/subscription fees beyond initial $2M
# - Integration and training costs
# - Ongoing maintenance and updates
# - Staff retraining/transition costs
#
# **Risk Factors:**
# - Implementation timeline risks affecting ROI timeline
# - Technology adoption curve by customers
# - Competitive response impact on projected benefits
#
# ### Questions for Other Experts:
#
# **To Operations:** What's our current cost per customer interaction, and what volume are we projecting the AI to handle?
#
# **To Technology:** Are there hidden infrastructure costs or integration complexities that could impact the $2M budget?
#
# **To Marketing/Sales:** How confident are we in the customer satisfaction improvements driving the revenue assumptions?
#
# Would you like me to model different scenarios or dive deeper into any specific financial component?## Technical Architecture Assessment: AI Customer Service Platform
#
# ### Technical Feasibility Analysis
#
# **Overall Assessment**: The project is technically feasible but requires careful planning around several critical components.
#
# ### Implementation Complexity Breakdown:
#
# **Core AI Components:**
# - **Natural Language Processing**: Modern L## MarketLM integration Research ( AssessmentGPT-4, Claude: AI Customer Service Platform
#
# ### Market, or Opportunity Analysis
#
# **Market Size & Growth proprietary models)
# - **Intent:** Recognition**: Multi-tier
# - Global classification system AI customer service market: $1.6 for routing
# - **KnowledgeB Base Integration**: Vector (2023) → databases for context retri $4eval
# - **.2B projecteConversation Management**: Stated (2 management across027 multi-turn interactions
#
# **)
# -Integration Challenges:**
# - CAGR of **C 27RM System Integration**: API.8% indicates compatibility with existing strong Salesforce/Hub tailSpot/winds forcustom systems
# - ** ourOmnichannel Support**: timing Unified experience across web chat
# - Enterprise, email, phone, segment social media
# - **Authentication ( & Securityour**: SS likelyO integration, target) data encryption, compliance ( growingGDPR, fastest CCPA)
# - **Legacy at System Connectivity**: Potential 32% need for middleware CAGR
#
# ###/API Competitive Landscape Assessment gateways
#
# ###
#
# **Current Technical Risk Assessment: Market
#
# **HIGH RISK:** Leaders
# - **Data Quality Dependencies:**
# - **Zen**: AIdesk Answer Bot** - performance directly tied to training data quality
# - ** Scalability Under40% market share, strong Load**: Real SM-time responseB presence requirements during
# - **Sales peak traffic
# - **Model Hallforce Einsteinucination**: Risk of AI** - Enterprise providing focus incorrect information
#
# **MEDIUM RISK:**, integrate
# - **Integrationd C Timeline**: ComplexRM advantage enterprise   integrations often excee
# - **Microsoft Botd estimates Framework** - Developer
# - **Performance Optimization-friendly, Azure**: Response integration
# - **Emerging time requirements vs. accuracy players:** trade Ada-offs
#
# ###, Infrastructure Inter Requirements Beyoncom Resolutiond $ Bot2M:
#
# **Potential gaining Hidden traction
#
# **Market Costs:**
# - **Clou Gapd Infrastructure**: $50- Identifie100K/year for productiond:**
# Most- solutionsgrade are AI hosting either
# - **Security Compliance**: Additional too basic $ (chat200-300bots) or ovK for enterpriseerly complex (enterprise-only security). ** requirements
# - **MonitoringMi/Observability**: Reald-market opportunity-time performance tracking systems** appears under
#
# ### Questions for Teamserved.
#
# ### Customer:
#
# **To Operations Nee**: What's our currentd Validation tech stack
#
# **Primary Pain Points ( and integration complexity score?
#
# **To Financevalidated through**: Have we fact industryored in ongoing surveys):**
# 1. **Cost cloud costs and potential pressure infrastructure scaling needs?
#
# The:** 73 1.2-1.% of companies4 year break-even timeline cite rising aligns with typical enterprise AI deployment support cycles, but integration complexity could extend this by costs as top 3 concern
# 2. **24-6 months./7 availability:** 68
#
# **% struggleRecommendation**: Proceed with with after phased implementation approach-hours coverage to
# 3. ** mitigate technicalConsistency risks.:** 61% report quality variation between agents
# 4. **Scalability:** 54% can't handle seasonal/peak demand spikes
#
# **Adoption Readiness Indicators:**
# - 78% of businesses already use some form of automated support
# - 64% plan to increase AI investment in customer service within 2 years
# - However, only 31% are "very satisfied" with current solutions
#
# ### Market Timing & Risk Assessment
#
# **Positive Timing Factors:**
# - Post-pandemic acceleration in digital customer expectations
# - Labor shortage driving automation adoption
# - Improved AI capabilities making solutions more viable
#
# **Market Risks:**
# - **Saturation concern:** 200+ vendors in chatbot/AI customer service space
# - **Buyer fatigue:** Many customers burned by previous AI implementations
# - **Economic uncertainty:** B2B software budgets under scrutiny
#
# ### Target Market Recommendation
#
# **Optimal ICP (Ideal Customer Profile):**
# - Mid-market companies (500-2,500 employees)
# - High customer interaction volume (>1,000 tickets/month)
# - Industries: E-commerce, SaaS, Financial Services, Healthcare
# - Current customer service costs >$500K annually
#
# ### Questions for Cross-Functional Validation:
#
# **To Technology Team:** How differentiated is our AI capability vs. existing solutions? What's our unique value proposition?
#
# **To Operations:** Can we validate the 150% ROI assumption with specific customer segments and use cases?
#
# **Based on market analysis, the 35.7% annualized ROI projected by finance appears achievable given strong market demand, but success will heavily depend on our differentiation strategy and target market focus.**
#
# Would you like me to dive deeper into any specific market segment or competitive analysis?# Risk Analysis: AI Customer Service Platform Launch
#
# ## Executive Summary
# The $2M investment in an AI customer service platform presents **MODERATE-HIGH RISK** with significant upside potential. While the 150% 3-year ROI projection appears achievable based on market conditions, several critical risks require immediate attention and mitigation strategies.
#
# ## Primary Risk Categories
#
# ### 1. FINANCIAL RISKS - **HIGH PRIORITY**
#
# **Investment Recovery Risk:**
# - **Issue**: 3-year ROI assumes consistent market adoption and retention
# - **Quantified Impact**: 25% customer churn could reduce ROI from 150% to 85%
# - **Mitigation**: Implement staged investment approach ($500K initial, remainder based on milestones)
#
# **Hidden Cost Escalation:**
# - **Issue**: Tech assessment reveals $50-100K annual cloud costs + $200-300K security compliance not in initial budget
# - **Quantified Impact**: Could increase total investment to $2.5-2.8M, reducing effective ROI to 110-120%
# - **Mitigation**: Establish 15% contingency fund ($300K) for infrastructure overruns
#
# ### 2. MARKET RISKS - **MEDIUM-HIGH PRIORITY**
#
# **Competitive Saturation:**
# - **Issue**: 200+ vendors in space with established players (Zendesk 40% market share)
# - **Impact**: Longer sales cycles, price pressure, higher customer acquisition costs
# - **Mitigation**: Focus on underserved mid-market segment (500-2,500 employees) as recommended
#
# **Economic Sensitivity:**
# - **Issue**: B2B software budgets under scrutiny during economic uncertainty
# - **Impact**: Extended sales cycles could delay break-even by 6-12 months
# - **Mitigation**: Develop flexible pricing models and ROI guarantee programs
#
# ### 3. TECHNICAL RISKS - **HIGH PRIORITY**
#
# **AI Performance Dependencies:**
# - **Issue**: Model hallucination and data quality directly impact customer satisfaction
# - **Impact**: Poor AI responses could lead to customer churn and brand damage
# - **Mitigation**: Implement human-in-the-loop fallback systems and continuous monitoring
#
# **Integration Complexity:**
# - **Issue**: Enterprise integrations often exceed timeline estimates by 3-6 months
# - **Impact**: Delayed revenue recognition, increased development costs
# - **Mitigation**: Conduct technical due diligence with target customers before full development
#
# ### 4. REGULATORY & COMPLIANCE RISKS - **MEDIUM PRIORITY**
#
# **Data Privacy Compliance:**
# - **Issue**: GDPR, CCPA, and evolving AI regulations
# - **Impact**: Potential fines, restricted market access
# - **Mitigation**: Build privacy-by-design architecture, engage compliance consultants early
#
# **AI Governance Requirements:**
# - **Issue**: Emerging AI liability and transparency requirements
# - **Impact**: Additional development costs, feature limitations
# - **Mitigation**: Monitor regulatory developments, implement audit trails
#
# ## Risk Mitigation Strategy
#
# ### Phase-Gate Investment Approach
# 1. **Phase 1** ($500K): MVP development and pilot customer validation
# 2. **Phase 2** ($750K): Market expansion after proof of concept
# 3. **Phase 3** ($750K): Full platform scaling
#
# ### Key Performance Indicators for Risk Monitoring
# - Customer acquisition cost vs. lifetime value ratio
# - AI accuracy rates (>95% target)
# - Integration completion timelines
# - Monthly recurring revenue growth
#
# ### Contingency Planning
# - **Scenario 1**: 50% ROI shortfall → Pivot to specific vertical market
# - **Scenario 2**: Technical delays → Partner with existing platform for faster market entry
# - **Scenario 3**: Funding shortfall → Seek additional $500K Series A extension
#
# ## Final Risk Assessment
#
# **Probability of Success**: 65-70%
# **Adjusted ROI Range**: 85-150% (accounting for identified risks)
# **Break-even Timeline**: 14-20 months (vs. projected 12-14 months)
#
# **RECOMMENDATION**: Proceed with investment using phase-gate approach and enhanced risk monitoring. The market opportunity is strong, but execution risks require careful management and contingency planning.
#
# **Critical Success Factors**:
# 1. Securing 2-3 pilot customers before Phase 2 investment
# 2. Achieving >95% AI accuracy in controlled tests
# 3. Maintaining customer acquisition costs below $25K per enterprise client
#
# ============================================================
# ============================================================
# Response: GraphResult(status=<Status.COMPLETED: 'completed'>, results={'finance_expert': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': "## Financial Assessment: AI Customer Service Platform\n\n### Initial ROI Analysis\nA 150% ROI over 3 years translates to:\n- **Total return**: $5M ($2M investment + $3M profit)\n- **Annualized ROI**: ~35.7%\n- **Break-even point**: Approximately 1.2-1.4 years\n\nThis is **strong performance** compared to typical enterprise software investments (15-25% annual ROI).\n\n### Key Financial Considerations I'd Explore:\n\n**Revenue Impact Drivers:**\n- Volume of customer interactions the AI will handle\n- Cost per interaction savings vs. current human agents\n- Potential revenue uplift from improved customer satisfaction/retention\n- Capacity to handle peak loads without additional hiring\n\n**Cost Structure Deep-Dive:**\n- Annual licensing/subscription fees beyond initial $2M\n- Integration and training costs\n- Ongoing maintenance and updates\n- Staff retraining/transition costs\n\n**Risk Factors:**\n- Implementation timeline risks affecting ROI timeline\n- Technology adoption curve by customers\n- Competitive response impact on projected benefits\n\n### Questions for Other Experts:\n\n**To Operations:** What's our current cost per customer interaction, and what volume are we projecting the AI to handle?\n\n**To Technology:** Are there hidden infrastructure costs or integration complexities that could impact the $2M budget?\n\n**To Marketing/Sales:** How confident are we in the customer satisfaction improvements driving the revenue assumptions?\n\nWould you like me to model different scenarios or dive deeper into any specific financial component?"}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[4.792102098464966], traces=[<strands.telemetry.metrics.Trace object at 0x7f39c7211580>], accumulated_usage={'inputTokens': 77, 'outputTokens': 342, 'totalTokens': 419}, accumulated_metrics={'latencyMs': 4772}), state={}, interrupts=None, structured_output=None), execution_time=4792, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 77, 'outputTokens': 342, 'totalTokens': 419}, accumulated_metrics={'latencyMs': 4772}, execution_count=1), 'tech_expert': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': "## Technical Architecture Assessment: AI Customer Service Platform\n\n### Technical Feasibility Analysis\n\n**Overall Assessment**: The project is technically feasible but requires careful planning around several critical components.\n\n### Implementation Complexity Breakdown:\n\n**Core AI Components:**\n- **Natural Language Processing**: Modern LLM integration (GPT-4, Claude, or proprietary models)\n- **Intent Recognition**: Multi-tier classification system for routing\n- **Knowledge Base Integration**: Vector databases for context retrieval\n- **Conversation Management**: State management across multi-turn interactions\n\n**Integration Challenges:**\n- **CRM System Integration**: API compatibility with existing Salesforce/HubSpot/custom systems\n- **Omnichannel Support**: Unified experience across web chat, email, phone, social media\n- **Authentication & Security**: SSO integration, data encryption, compliance (GDPR, CCPA)\n- **Legacy System Connectivity**: Potential need for middleware/API gateways\n\n### Technical Risk Assessment:\n\n**HIGH RISK:**\n- **Data Quality Dependencies**: AI performance directly tied to training data quality\n- **Scalability Under Load**: Real-time response requirements during peak traffic\n- **Model Hallucination**: Risk of AI providing incorrect information\n\n**MEDIUM RISK:**\n- **Integration Timeline**: Complex enterprise integrations often exceed estimates\n- **Performance Optimization**: Response time requirements vs. accuracy trade-offs\n\n### Infrastructure Requirements Beyond $2M:\n\n**Potential Hidden Cos ...
# =============Node execution order:==========================
# ============================================================
# Executed: finance_expert
# Executed: tech_expert
# Executed: market_expert
# Executed: risk_analyst
# =============Graph metrics:=================================
# ============================================================
# Total nodes: 4
# Completed nodes: 4
# Failed nodes: 0
# Execution time: 0ms
# Token usage: {'inputTokens': 2176, 'outputTokens': 2474, 'totalTokens': 4650}
# Financial Advisor:
# ============================================================
# ============================================================
# ## Financial Assessment: AI Customer Service Platform
#
# ### Initial ROI Analysis
# A 150% ROI over 3 years translates to:
# - **Total return**: $5M ($2M investment + $3M profit)
# - **Annualized ROI**: ~35.7%
# - **Break-even point**: Approximately 1.2-1.4 years
#
# This is **strong performance** compared to typical enterprise software investments (15-25% annual ROI).
#
# ### Key Financial Considerations I'd Explore:
#
# **Revenue Impact Drivers:**
# - Volume of customer interactions the AI will handle
# - Cost per interaction savings vs. current human agents
# - Potential revenue uplift from improved customer satisfaction/retention
# - Capacity to handle peak loads without additional hiring
#
# **Cost Structure Deep-Dive:**
# - Annual licensing/subscription fees beyond initial $2M
# - Integration and training costs
# - Ongoing maintenance and updates
# - Staff retraining/transition costs
#
# **Risk Factors:**
# - Implementation timeline risks affecting ROI timeline
# - Technology adoption curve by customers
# - Competitive response impact on projected benefits
#
# ### Questions for Other Experts:
#
# **To Operations:** What's our current cost per customer interaction, and what volume are we projecting the AI to handle?
#
# **To Technology:** Are there hidden infrastructure costs or integration complexities that could impact the $2M budget?
#
# **To Marketing/Sales:** How confident are we in the customer satisfaction improvements driving the revenue assumptions?
#
# Would you like me to model different scenarios or dive deeper into any specific financial component?
#
#
#
# Technical Expert:
# ============================================================
# ============================================================
# ## Technical Architecture Assessment: AI Customer Service Platform
#
# ### Technical Feasibility Analysis
#
# **Overall Assessment**: The project is technically feasible but requires careful planning around several critical components.
#
# ### Implementation Complexity Breakdown:
#
# **Core AI Components:**
# - **Natural Language Processing**: Modern LLM integration (GPT-4, Claude, or proprietary models)
# - **Intent Recognition**: Multi-tier classification system for routing
# - **Knowledge Base Integration**: Vector databases for context retrieval
# - **Conversation Management**: State management across multi-turn interactions
#
# **Integration Challenges:**
# - **CRM System Integration**: API compatibility with existing Salesforce/HubSpot/custom systems
# - **Omnichannel Support**: Unified experience across web chat, email, phone, social media
# - **Authentication & Security**: SSO integration, data encryption, compliance (GDPR, CCPA)
# - **Legacy System Connectivity**: Potential need for middleware/API gateways
#
# ### Technical Risk Assessment:
#
# **HIGH RISK:**
# - **Data Quality Dependencies**: AI performance directly tied to training data quality
# - **Scalability Under Load**: Real-time response requirements during peak traffic
# - **Model Hallucination**: Risk of AI providing incorrect information
#
# **MEDIUM RISK:**
# - **Integration Timeline**: Complex enterprise integrations often exceed estimates
# - **Performance Optimization**: Response time requirements vs. accuracy trade-offs
#
# ### Infrastructure Requirements Beyond $2M:
#
# **Potential Hidden Costs:**
# - **Cloud Infrastructure**: $50-100K/year for production-grade AI hosting
# - **Security Compliance**: Additional $200-300K for enterprise security requirements
# - **Monitoring/Observability**: Real-time performance tracking systems
#
# ### Questions for Team:
#
# **To Operations**: What's our current tech stack and integration complexity score?
#
# **To Finance**: Have we factored in ongoing cloud costs and potential infrastructure scaling needs?
#
# The 1.2-1.4 year break-even timeline aligns with typical enterprise AI deployment cycles, but integration complexity could extend this by 3-6 months.
#
# **Recommendation**: Proceed with phased implementation approach to mitigate technical risks.
#
#
#
# Market Researcher:
# ============================================================
# ============================================================
# ## Market Research Assessment: AI Customer Service Platform
#
# ### Market Opportunity Analysis
#
# **Market Size & Growth:**
# - Global AI customer service market: $1.6B (2023) → $4.2B projected (2027)
# - CAGR of 27.8% indicates strong tailwinds for our timing
# - Enterprise segment (our likely target) growing fastest at 32% CAGR
#
# ### Competitive Landscape Assessment
#
# **Current Market Leaders:**
# - **Zendesk Answer Bot** - 40% market share, strong SMB presence
# - **Salesforce Einstein** - Enterprise focus, integrated CRM advantage
# - **Microsoft Bot Framework** - Developer-friendly, Azure integration
# - **Emerging players:** Ada, Intercom Resolution Bot gaining traction
#
# **Market Gap Identified:**
# Most solutions are either too basic (chatbots) or overly complex (enterprise-only). **Mid-market opportunity** appears underserved.
#
# ### Customer Need Validation
#
# **Primary Pain Points (validated through industry surveys):**
# 1. **Cost pressure:** 73% of companies cite rising support costs as top concern
# 2. **24/7 availability:** 68% struggle with after-hours coverage
# 3. **Consistency:** 61% report quality variation between agents
# 4. **Scalability:** 54% can't handle seasonal/peak demand spikes
#
# **Adoption Readiness Indicators:**
# - 78% of businesses already use some form of automated support
# - 64% plan to increase AI investment in customer service within 2 years
# - However, only 31% are "very satisfied" with current solutions
#
# ### Market Timing & Risk Assessment
#
# **Positive Timing Factors:**
# - Post-pandemic acceleration in digital customer expectations
# - Labor shortage driving automation adoption
# - Improved AI capabilities making solutions more viable
#
# **Market Risks:**
# - **Saturation concern:** 200+ vendors in chatbot/AI customer service space
# - **Buyer fatigue:** Many customers burned by previous AI implementations
# - **Economic uncertainty:** B2B software budgets under scrutiny
#
# ### Target Market Recommendation
#
# **Optimal ICP (Ideal Customer Profile):**
# - Mid-market companies (500-2,500 employees)
# - High customer interaction volume (>1,000 tickets/month)
# - Industries: E-commerce, SaaS, Financial Services, Healthcare
# - Current customer service costs >$500K annually
#
# ### Questions for Cross-Functional Validation:
#
# **To Technology Team:** How differentiated is our AI capability vs. existing solutions? What's our unique value proposition?
#
# **To Operations:** Can we validate the 150% ROI assumption with specific customer segments and use cases?
#
# **Based on market analysis, the 35.7% annualized ROI projected by finance appears achievable given strong market demand, but success will heavily depend on our differentiation strategy and target market focus.**
#
# Would you like me to dive deeper into any specific market segment or competitive analysis?

# %% [markdown]
# ### Branching with conditions
#
# Let's create an agent graph that would classify the request and depending on conditions we define in the code - will route the request either to technical or business agent.
#
# Take a close look on differences between the node execution order and number of nodes executed in this graph based on two different prompts.
#
# <div style="text-align:left">
#     <img src="images/conditional.png" width="55%" />
# </div>

# %%
#Initialize an agent with agent_graph capability
from strands.multiagent import GraphBuilder

mesh_agent = Agent()
# Create specialized agents

classifier = Agent(name="classifier", system_prompt="You are an agent responsible for classification of the report request, return only Technical or Business clasification.")
technical_report = Agent(name="technical_expert", system_prompt="You are a technical expert htat focuses on providing short summary from technical perspective")
business_report = Agent(name="business_expert", system_prompt="You are a business expert that focuses on providing short summary from business perspective")

# Build the graph
builder = GraphBuilder()

# Add nodes
builder.add_node(classifier, "classifier")
builder.add_node(technical_report, "technical_report")
builder.add_node(business_report, "business_report")

def is_technical(state):
    classifier_result = state.results.get("classifier")
    if not classifier_result:
        return False
    result_text = str(classifier_result.result)
    return "technical" in result_text.lower()

def is_business(state):
    classifier_result = state.results.get("classifier")
    if not classifier_result:
        return False
    result_text = str(classifier_result.result)
    return "business" in result_text.lower()

# Add edges (dependencies)
builder.add_edge("classifier", "technical_report", condition=is_technical)
builder.add_edge("classifier", "business_report", condition=is_business)

# Set entry points (optional - will be auto-detected if not specified)
builder.set_entry_point("classifier")

# Build the graph
graph = builder.build()

print("============================================================")
print("============================================================")

#Execute task on newly built graph
result = graph("Provide report on technical aspect of working from home, outline things to consider and key risk factors")
print("\n")
print("============================================================")
print("============================================================")

print(f"Response: {result}")

print("=============Node execution order:==========================")
print("============================================================")

# See which nodes were executed and in what order
for node in result.execution_order:
    print(f"Executed: {node.node_id}")

print("=============Graph metrics:=================================")
print("============================================================")


# Get performance metrics
print(f"Total nodes: {result.total_nodes}")
print(f"Completed nodes: {result.completed_nodes}")
print(f"Failed nodes: {result.failed_nodes}")
print(f"Execution time: {result.execution_time}ms")
print(f"Token usage: {result.accumulated_usage}")

# Get results from specific nodes

print("Classifier:")
print("============================================================")
print("============================================================")
print(result.results["classifier"].result)
print("\n")

#Execute task on newly built graph
result = graph("Provide report on business impact of working from home, outline things to consider and key risk factors")
print("\n")
print("============================================================")
print("============================================================")

print(f"Response: {result}")

print("=============Node execution order:==========================")
print("============================================================")

# See which nodes were executed and in what order
for node in result.execution_order:
    print(f"Executed: {node.node_id}")

print("=============Graph metrics:=================================")
print("============================================================")


# Get performance metrics
print(f"Total nodes: {result.total_nodes}")
print(f"Completed nodes: {result.completed_nodes}")
print(f"Failed nodes: {result.failed_nodes}")
print(f"Execution time: {result.execution_time}ms")
print(f"Token usage: {result.accumulated_usage}")

# Get results from specific nodes

print("Classifier:")
print("============================================================")
print("============================================================")
print(result.results["classifier"].result)
print("\n")
# Out:
# Graph without execution limits may run indefinitely if cycles exist
# ============================================================
# ============================================================
# Technical# Technical Aspects of Working From Home: Technical Report
#
# ## Key Technical Considerations
#
# ### Network Infrastructure
# - **Internet Connectivity**: Minimum 25 Mbps download/3 Mbps upload for standard operations
# - **Redundancy**: Backup internet connection (mobile hotspot/secondary ISP)
# - **Network Security**: VPN implementation, firewall configuration, secure Wi-Fi protocols (WPA3)
#
# ### Hardware Requirements
# - **Computing Power**: Adequate CPU/RAM for workload demands
# - **Display Setup**: Dual monitor configuration for productivity optimization
# - **Audio/Video**: Quality webcam, noise-canceling headset for remote collaboration
# - **Backup Power**: UPS systems for critical operations
#
# ### Software & Security Stack
# - **Collaboration Tools**: Video conferencing, project management platforms
# - **Security Software**: Endpoint protection, multi-factor authentication
# - **Cloud Services**: Secure file sharing, backup solutions
# - **Remote Access**: VPN clients, remote desktop protocols
#
# ## Critical Risk Factors
#
# ### Security Vulnerabilities
# - **Endpoint Exposure**: Increased attack surface on home networks
# - **Data Leakage**: Unsecured home Wi-Fi, shared devices
# - **Phishing Attacks**: Higher susceptibility in isolated environments
#
# ### Technical Reliability Issues
# - **Single Points of Failure**: Internet outages, hardware failures
# - **Performance Degradation**: Bandwidth limitations during peak usage
# - **Support Challenges**: Limited on-site technical assistance
#
# ### Compliance Concerns
# - **Data Residency**: Ensuring data remains in authorized locations
# - **Audit Trails**: Maintaining proper logging and monitoring
# - **Regulatory Requirements**: GDPR, HIPAA, industry-specific standards
#
# ## Recommended Mitigation Strategies
# - Implement zero-trust security model
# - Deploy centralized device management (MDM/EMM)
# - Establish 24/7 remote support capabilities
# - Regular security awareness training
#
# ============================================================
# ============================================================
# Response: GraphResult(status=<Status.COMPLETED: 'completed'>, results={'classifier': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'Technical'}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[1.7805132865905762], traces=[<strands.telemetry.metrics.Trace object at 0x7f39c534d700>], accumulated_usage={'inputTokens': 46, 'outputTokens': 4, 'totalTokens': 50}, accumulated_metrics={'latencyMs': 1761}), state={}, interrupts=None, structured_output=None), execution_time=1781, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 46, 'outputTokens': 4, 'totalTokens': 50}, accumulated_metrics={'latencyMs': 1761}, execution_count=1), 'technical_report': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': '# Technical Aspects of Working From Home: Technical Report\n\n## Key Technical Considerations\n\n### Network Infrastructure\n- **Internet Connectivity**: Minimum 25 Mbps download/3 Mbps upload for standard operations\n- **Redundancy**: Backup internet connection (mobile hotspot/secondary ISP)\n- **Network Security**: VPN implementation, firewall configuration, secure Wi-Fi protocols (WPA3)\n\n### Hardware Requirements\n- **Computing Power**: Adequate CPU/RAM for workload demands\n- **Display Setup**: Dual monitor configuration for productivity optimization\n- **Audio/Video**: Quality webcam, noise-canceling headset for remote collaboration\n- **Backup Power**: UPS systems for critical operations\n\n### Software & Security Stack\n- **Collaboration Tools**: Video conferencing, project management platforms\n- **Security Software**: Endpoint protection, multi-factor authentication\n- **Cloud Services**: Secure file sharing, backup solutions\n- **Remote Access**: VPN clients, remote desktop protocols\n\n## Critical Risk Factors\n\n### Security Vulnerabilities\n- **Endpoint Exposure**: Increased attack surface on home networks\n- **Data Leakage**: Unsecured home Wi-Fi, shared devices\n- **Phishing Attacks**: Higher susceptibility in isolated environments\n\n### Technical Reliability Issues\n- **Single Points of Failure**: Internet outages, hardware failures\n- **Performance Degradation**: Bandwidth limitations during peak usage\n- **Support Challenges**: Limited on-site technical assistance\n\n### Compliance Concerns\n- **Data Residency**: Ensuring data remains in authorized locations\n- **Audit Trails**: Maintaining proper logging and monitoring\n- **Regulatory Requirements**: GDPR, HIPAA, industry-specific standards\n\n## Recommended Mitigation Strategies\n- Implement zero-trust security model\n- Deploy centralized device management (MDM/EMM)\n- Establish 24/7 remote support capabilities\n- Regular security awareness training'}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[5.667571067810059], traces=[<strands.telemetry.metrics.Trace object at 0x7f39c431c5f0>], accumulated_usage={'inputTokens': 60, 'outputTokens': 433, 'totalTokens': 493}, accumulated_metrics={'latencyMs': 5648}), state={}, interrupts=None, structured_output=None), execution_time=5668, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 60, 'outputTokens': 433, 'totalTokens': 493}, accumulated_metrics={'latencyMs': 5648}, execution_count=1)}, accumulated_usage={'inputTokens': 106, 'outputTokens': 437, 'totalTokens': 543}, accumulated_metrics={'latencyMs': 7409}, execution_count=2, execution_time=0, total_nodes=3, completed_nodes=2, failed_nodes=0, execution_order=[GraphNode(node_id='classifier', executor=<strands.agent.agent.Agent object at 0x7f39d4e641a0>, dependencies=set(), execution_status=<Status.COMPLETED: 'completed'>, result=NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'Technical'}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[1.7805132865905762], traces=[<strands.te ...
# =============Node execution order:==========================
# ============================================================
# Executed: classifier
# Executed: technical_report
# =============Graph metrics:=================================
# ============================================================
# Total nodes: 3
# Completed nodes: 2
# Failed nodes: 0
# Execution time: 0ms
# Token usage: {'inputTokens': 106, 'outputTokens': 437, 'totalTokens': 543}
# Classifier:
# ============================================================
# ============================================================
# Technical
#
#
#
# Business# Business Impact of Working From Home: Executive Summary
#
# ## Key Business Impacts
#
# **Positive Impacts:**
# - **Cost Reduction**: 20-30% savings on office space, utilities, and facilities
# - **Talent Pool Expansion**: Access to global workforce without geographical constraints
# - **Productivity Gains**: 13-50% increase reported by companies like Stanford study participants
# - **Employee Retention**: 95% of companies report improved retention rates
#
# **Negative Impacts:**
# - **Collaboration Challenges**: 67% decline in spontaneous interactions
# - **Innovation Reduction**: Decreased cross-functional collaboration affecting product development
# - **Management Complexity**: Increased oversight costs and performance monitoring needs
#
# ## Critical Considerations
#
# ### Infrastructure & Technology
# - Cybersecurity investment requirements (30-40% budget increase)
# - IT support scaling for distributed workforce
# - Digital collaboration platform licensing costs
#
# ### Legal & Compliance
# - Multi-jurisdiction employment law compliance
# - Worker compensation and liability coverage gaps
# - Data protection across home networks
#
# ### Cultural Impact
# - Company culture maintenance challenges
# - Onboarding new employees remotely
# - Knowledge transfer and mentorship difficulties
#
# ## Key Risk Factors
#
# **High Priority:**
# 1. **Security Vulnerabilities**: 238% increase in cyberattacks on remote workers
# 2. **Productivity Measurement**: Difficulty tracking actual output vs. activity
# 3. **Talent Competition**: Increased poaching from competitors accessing same talent pool
#
# **Medium Priority:**
# - Employee burnout from blurred work-life boundaries
# - Communication gaps leading to project delays
# - Reduced client relationship quality
#
# ## Recommendations
# - Implement hybrid model (2-3 days office) for optimal balance
# - Invest in robust security infrastructure upfront
# - Establish clear performance metrics and communication protocols
# - Budget 15-25% additional for remote work infrastructure and management tools
#
# ============================================================
# ============================================================
# Response: GraphResult(status=<Status.COMPLETED: 'completed'>, results={'classifier': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'Business'}]}, metrics=EventLoopMetrics(cycle_count=2, tool_metrics={}, cycle_durations=[1.7805132865905762, 0.7405734062194824], traces=[<strands.telemetry.metrics.Trace object at 0x7f39c534d700>, <strands.telemetry.metrics.Trace object at 0x7f39c431c2c0>], accumulated_usage={'inputTokens': 118, 'outputTokens': 8, 'totalTokens': 126}, accumulated_metrics={'latencyMs': 2497}), state={}, interrupts=None, structured_output=None), execution_time=741, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 118, 'outputTokens': 8, 'totalTokens': 126}, accumulated_metrics={'latencyMs': 2497}, execution_count=1), 'business_report': NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': '# Business Impact of Working From Home: Executive Summary\n\n## Key Business Impacts\n\n**Positive Impacts:**\n- **Cost Reduction**: 20-30% savings on office space, utilities, and facilities\n- **Talent Pool Expansion**: Access to global workforce without geographical constraints\n- **Productivity Gains**: 13-50% increase reported by companies like Stanford study participants\n- **Employee Retention**: 95% of companies report improved retention rates\n\n**Negative Impacts:**\n- **Collaboration Challenges**: 67% decline in spontaneous interactions\n- **Innovation Reduction**: Decreased cross-functional collaboration affecting product development\n- **Management Complexity**: Increased oversight costs and performance monitoring needs\n\n## Critical Considerations\n\n### Infrastructure & Technology\n- Cybersecurity investment requirements (30-40% budget increase)\n- IT support scaling for distributed workforce\n- Digital collaboration platform licensing costs\n\n### Legal & Compliance\n- Multi-jurisdiction employment law compliance\n- Worker compensation and liability coverage gaps\n- Data protection across home networks\n\n### Cultural Impact\n- Company culture maintenance challenges\n- Onboarding new employees remotely\n- Knowledge transfer and mentorship difficulties\n\n## Key Risk Factors\n\n**High Priority:**\n1. **Security Vulnerabilities**: 238% increase in cyberattacks on remote workers\n2. **Productivity Measurement**: Difficulty tracking actual output vs. activity\n3. **Talent Competition**: Increased poaching from competitors accessing same talent pool\n\n**Medium Priority:**\n- Employee burnout from blurred work-life boundaries\n- Communication gaps leading to project delays\n- Reduced client relationship quality\n\n## Recommendations\n- Implement hybrid model (2-3 days office) for optimal balance\n- Invest in robust security infrastructure upfront\n- Establish clear performance metrics and communication protocols\n- Budget 15-25% additional for remote work infrastructure and management tools'}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[5.372203826904297], traces=[<strands.telemetry.metrics.Trace object at 0x7f39c431f4a0>], accumulated_usage={'inputTokens': 59, 'outputTokens': 408, 'totalTokens': 467}, accumulated_metrics={'latencyMs': 5353}), state={}, interrupts=None, structured_output=None), execution_time=5372, status=<Status.COMPLETED: 'completed'>, accumulated_usage={'inputTokens': 59, 'outputTokens': 408, 'totalTokens': 467}, accumulated_metrics={'latencyMs': 5353}, execution_count=1)}, accumulated_usage={'inputTokens': 177, 'outputTokens': 416, 'totalTokens': 593}, accumulated_metrics={'latencyMs': 7850}, execution_count=2, execution_time=0, total_nodes=3, completed_nodes=2, failed_nodes=0, execution_order=[GraphNode(node_id='classifier', executor=<strands.agent.agent.Agent object at 0x7f39d4e641a0>, dependencies=set(), execution_status=<Status.COMPLETED: 'completed'>, result=NodeResult(result=AgentResult(stop_reason='end_turn', message={'role': 'a ...
# =============Node execution order:==========================
# ============================================================
# Executed: classifier
# Executed: business_report
# =============Graph metrics:=================================
# ============================================================
# Total nodes: 3
# Completed nodes: 2
# Failed nodes: 0
# Execution time: 0ms
# Token usage: {'inputTokens': 177, 'outputTokens': 416, 'totalTokens': 593}
# Classifier:
# ============================================================
# ============================================================
# Business

# %% [markdown]
# ## Key Takeaways and Best Practices
#
#
# ### Best Practices:
#
# **Design for acyclicity:** Ensure your graph has no cycles</p>
# **Use meaningful node IDs:** Choose descriptive names for nodes</p>
# **Validate graph structure:** The builder will check for cycles and validate entry points</p>
# **Handle node failures:** Consider how failures in one node affect the overall workflow</p>
# **Use conditional edges:** For dynamic workflows based on intermediate results</p>
# **Consider parallelism:** Independent branches can execute concurrently</p>
# **Nest multi-agent patterns:** Use Swarms within Graphs for complex workflows</p>
# **Leverage multi-modal inputs:** Use ContentBlocks for rich inputs including images</p>
#
# ## Conclusion
#
# You've now mastered the fundamentals of building multi-agent systems with Strands Agent Graph! You can create sophisticated networks of specialized AI agents that collaborate to solve complex problems.
#
# The key to successful multi-agent systems is:
# - Matching topology to use case
# - Defining clear agent roles and responsibilities
# - Establishing proper communication patterns
# - Managing resources and cleanup effectively
#
# From here, you can build increasingly sophisticated systems for real-world applications in research, content creation, decision-making, customer service, and beyond.
