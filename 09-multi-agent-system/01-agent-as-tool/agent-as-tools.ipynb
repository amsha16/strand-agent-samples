# %% [markdown]
# # Agents as Tools with Strands Agents

# %% [markdown]
# "Agents as Tools" is an architectural pattern in AI systems where specialized AI agents are wrapped as callable functions (tools) that can be used by other agents. This creates a hierarchical structure where:
#
# 1. A primary "orchestrator" agent handles user interaction and determines which specialized agent to call
#
# 2. Specialized "tool agents" perform domain-specific tasks when called by the orchestrator
#
# This approach mimics human team dynamics, where a manager coordinates specialists, each bringing unique expertise to solve complex problems. Rather than a single agent trying to handle everything, tasks are delegated to the most appropriate specialized agent.

# %% [markdown]
# ## Key Benefits and Core Principles

# %% [markdown]
# The "Agents as Tools" pattern offers several advantages:
#
# - Separation of concerns: Each agent has a focused area of responsibility, making the system easier to understand and maintain
# - Hierarchical delegation: The orchestrator decides which specialist to invoke, creating a clear chain of command
# - Modular architecture: Specialists can be added, removed, or modified independently without affecting the entire system
# - Improved performance: Each agent can have tailored system prompts and tools optimized for its specific task

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: strands-agents in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (1.18.0)
# Requirement already satisfied: strands-agents-tools in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (0.2.16)
# Requirement already satisfied: boto3<2.0.0,>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.41.5)
# Requirement already satisfied: botocore<2.0.0,>=1.29.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.41.5)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.17.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (4.25.1)
# Requirement already satisfied: mcp<2.0.0,>=1.11.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.22.0)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.38.0)
# Requirement already satisfied: opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.59b0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.38.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (2.12.5)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents->-r requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: s3transfer<0.16.0,>=0.15.0 in /opt/conda/lib/python3.12/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (0.15.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.12/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.12/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (0.29.0)
# Requirement already satisfied: anyio>=4.5 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (4.12.0)
# Requirement already satisfied: httpx-sse>=0.4 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (2.12.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /opt/conda/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: starlette>=0.27 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.50.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in /opt/conda/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.38.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 1)) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 1)) (3.23.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.59b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.59b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (1.17.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.59b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.59b0)
# Requirement already satisfied: packaging>=18.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.59b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents->-r requirements.txt (line 1)) (2.41.5)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (3.13.2)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.3)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.0)
# Requirement already satisfied: markdownify<2.0.0,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.2.2)
# Requirement already satisfied: pillow<12.0.0,>=11.2.1 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (11.3.0)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.51 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (3.0.52)
# Requirement already satisfied: requests<3.0.0,>=2.28.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (2.32.5)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (14.2.0)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.25.0)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in /opt/conda/lib/python3.12/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (9.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.22.0)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /opt/conda/lib/python3.12/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (4.14.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.12/site-packages (from beautifulsoup4<5,>=4.9->markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.8)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.12/site-packages (from prompt-toolkit<4.0.0,>=3.0.51->strands-agents-tools->-r requirements.txt (line 2)) (0.2.14)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (2025.11.12)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.12/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.12/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.19.2)
# Requirement already satisfied: slack_sdk<4,>=3.35.0 in /opt/conda/lib/python3.12/site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools->-r requirements.txt (line 2)) (3.37.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx>=0.27.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/conda/lib/python3.12/site-packages (from pydantic-settings>=2.5.2->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (1.2.1)
# Requirement already satisfied: cryptography>=3.4.0 in /opt/conda/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (2.23)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.12/site-packages (from uvicorn>=0.31.1->mcp<2.0.0,>=1.11.0->strands-agents->-r requirements.txt (line 1)) (8.3.1)

# %%
import os

from strands import Agent, tool
from strands_tools import file_write, http_request

# %% [markdown]
# In this module we will be creating an orchestrator based multi-agent workflow.
#
# <div style="text-align:left">
#     <img src="images/architecture.png" width="75%" />
# </div>
#
# We will also explore `use_llm` which allows use to create nested agents.

# %% [markdown]
# ## Research Agent

# %% [markdown]
# Lets first create a basic reasearch assistant with http_request tool.

# %%
RESEARCH_ASSISTANT_PROMPT = """You are a specialized research assistant. Focus only on providing
factual, well-sourced information in response to research questions.
Always cite your sources when possible."""

# %%
research_agent = Agent(
    model="us.anthropic.claude-3-7-sonnet-20250219-v1:0",
    system_prompt=RESEARCH_ASSISTANT_PROMPT,
    tools=[http_request],  # Here you can enable an agentic ai search tool
)

query = "Overview of Amazon Bedrock and its features"
# Call the agent and return its response
response = research_agent(query)
# Out:
# I'll provide you with an overview of Amazon Bedrock and its features. Let me gather the most up-to-date information from Amazon's official resources.
# Tool #1: http_request
# ╭──────────────────────────────────── 🚀 HTTP Request Preview: GET /bedrock/ ─────────────────────────────────────╮
# │                                                                                                                 │
# │   Method    GET                                                                                                 │
# │   URL       https://aws.amazon.com/bedrock/                                                                     │
# │   Headers   {}                                                                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Sending request...
# ╭──────────────────────────────────────────── ✅ HTTP Response: 200  ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │     Status         200                                                                                          │
# │     URL            https://aws.amazon.com/bedrock/                                                              │
# │     Content-Type   text/html;charset=utf-8                                                                      │
# │     Size           258,814 bytes (252.7 KB)                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                                  Response Headers
# ╭───────────────────────────┬─────────────────────────────────────────────────────────────────────────────────────╮
# │ Header                    │ Value                                                                               │
# ├───────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────┤
# │ Content-Type              │ text/html;charset=utf-8                                                             │
# │ Transfer-Encoding         │ chunked                                                                             │
# │ Connection                │ keep-alive                                                                          │
# │ Date                      │ Sat, 29 Nov 2025 16:15:20 GMT                                                       │
# │ Set-Cookie                │ aws-priv=eyJ2IjoxLCJldSI6MCwic3QiOjB9; Version=1; Comment="Anonymous cookie for     │
# │                           │ privacy regulations"...                                                             │
# │ X-Content-Type-Options    │ nosniff                                                                             │
# │ Server                    │ Server                                                                              │
# │ X-Frame-Options           │ SAMEORIGIN                                                                          │
# │ X-XSS-Protection          │ 1; mode=block                                                                       │
# │ Strict-Transport-Security │ max-age=47304000; includeSubDomains                                                 │
# │ x-amz-id-1                │ BC31370E3A624549BE03                                                                │
# │ Last-Modified             │ Tue, 25 Nov 2025 22:21:55 GMT                                                       │
# │ vary                      │ accept-encoding                                                                     │
# │ Content-Encoding          │ gzip                                                                                │
# │ X-Cache                   │ Miss from cloudfront                                                                │
# │ Via                       │ 1.1 f94332f6513a4c7b3f2217e6b2ddc08c.cloudfront.net (CloudFront)                    │
# │ X-Amz-Cf-Pop              │ HIO52-P2                                                                            │
# │ X-Amz-Cf-Id               │ UO4gL77Ie25HJLIt-ut2SChggMPsX1jY6qLnbjWPDNeCXsReePuVIg==                            │
# ╰───────────────────────────┴─────────────────────────────────────────────────────────────────────────────────────╯
# Let me gather more specific information about Amazon Bedrock features from their documentation:
# Tool #2: http_request
# ╭────────────────── 🚀 HTTP Request Preview: GET /bedrock/latest/userguide/what-is-bedrock.html ──────────────────╮
# │                                                                                                                 │
# │   Method    GET                                                                                                 │
# │   URL       https://docs.aws.amazon.com/bedrock/latest/userguide/what-is-bedrock.html                           │
# │   Headers   {}                                                                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Sending request...
# ╭─────────────────────────────────────────── ✅ HTTP Response: 200 OK ────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │     Status         200 OK                                                                                       │
# │     URL            https://docs.aws.amazon.com/bedrock/latest/userguide/what-is-bedrock.html                    │
# │     Content-Type   text/html                                                                                    │
# │     Size           16,575 bytes (16.2 KB)                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                                  Response Headers
# ╭───────────────────────────┬─────────────────────────────────────────────────────────────────────────────────────╮
# │ Header                    │ Value                                                                               │
# ├───────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────┤
# │ Content-Type              │ text/html                                                                           │
# │ Content-Length            │ 4543                                                                                │
# │ Connection                │ keep-alive                                                                          │
# │ Date                      │ Sat, 29 Nov 2025 16:15:29 GMT                                                       │
# │ Content-Encoding          │ gzip                                                                                │
# │ Server                    │ Server                                                                              │
# │ Cache-Control             │ no-store, no-cache, must-revalidate                                                 │
# │ Expires                   │ Thu, 01 Jan 1970 00:00:00 GMT                                                       │
# │ X-Frame-Options           │ SAMEORIGIN                                                                          │
# │ Strict-Transport-Security │ max-age=47304000; includeSubDomains                                                 │
# │ X-XSS-Protection          │ 1; mode=block                                                                       │
# │ X-Content-Type-Options    │ nosniff, nosniff                                                                    │
# │ Content-Security-Policy   │ upgrade-insecure-requests; script-src 'self' 'unsafe-inline' *.awsstatic.com        │
# │                           │ *.cdn.uis.awsstatic.com...                                                          │
# │ Last-Modified             │ Fri, 28 Nov 2025 06:33:54 GMT                                                       │
# │ Accept-Ranges             │ bytes                                                                               │
# │ ETag                      │ "FDuS/Xe94fLyJxpnmLeL0IC6Qlc=-gzip"                                                 │
# │ Vary                      │ Accept-Encoding                                                                     │
# │ X-Cache                   │ Miss from cloudfront                                                                │
# │ Via                       │ 1.1 7d14d4fc1c149f1d429681a4c414c21a.cloudfront.net (CloudFront)                    │
# │ X-Amz-Cf-Pop              │ HIO52-P4                                                                            │
# │ X-Amz-Cf-Id               │ R_zEuC3CK_ek_WKzIummrzfdVqOQ_vzL0itKmfw6OevfxNpo8pi5sQ==                            │
# ╰───────────────────────────┴─────────────────────────────────────────────────────────────────────────────────────╯
# Let me get more information about Amazon Bedrock's features:
# Tool #3: http_request
# ╭──────────────────────────────── 🚀 HTTP Request Preview: GET /bedrock/features/ ────────────────────────────────╮
# │                                                                                                                 │
# │   Method    GET                                                                                                 │
# │   URL       https://aws.amazon.com/bedrock/features/                                                            │
# │   Headers   {}                                                                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Sending request...
# ╭──────────────────────────────────────────── ✅ HTTP Response: 200  ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │     Status         200                                                                                          │
# │     URL            https://aws.amazon.com/bedrock/                                                              │
# │     Content-Type   text/html;charset=utf-8                                                                      │
# │     Size           258,814 bytes (252.7 KB)                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────── Redirect Information ───────╮
# │                                    │
# │ Followed 1 redirect(s): 301 -> 200 │
# │                                    │
# ╰────────────────────────────────────╯
#                                                  Response Headers
# ╭───────────────────────────┬─────────────────────────────────────────────────────────────────────────────────────╮
# │ Header                    │ Value                                                                               │
# ├───────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────┤
# │ Content-Type              │ text/html;charset=utf-8                                                             │
# │ Transfer-Encoding         │ chunked                                                                             │
# │ Connection                │ keep-alive                                                                          │
# │ Date                      │ Sat, 29 Nov 2025 16:15:37 GMT                                                       │
# │ Set-Cookie                │ aws-priv=eyJ2IjoxLCJldSI6MCwic3QiOjB9; Version=1; Comment="Anonymous cookie for     │
# │                           │ privacy regulations"...                                                             │
# │ X-Content-Type-Options    │ nosniff                                                                             │
# │ Server                    │ Server                                                                              │
# │ X-Frame-Options           │ SAMEORIGIN                                                                          │
# │ X-XSS-Protection          │ 1; mode=block                                                                       │
# │ Strict-Transport-Security │ max-age=47304000; includeSubDomains                                                 │
# │ x-amz-id-1                │ 10AA318A18624C2BB36E                                                                │
# │ Last-Modified             │ Tue, 25 Nov 2025 22:21:55 GMT                                                       │
# │ vary                      │ accept-encoding                                                                     │
# │ Content-Encoding          │ gzip                                                                                │
# │ X-Cache                   │ Miss from cloudfront                                                                │
# │ Via                       │ 1.1 f94332f6513a4c7b3f2217e6b2ddc08c.cloudfront.net (CloudFront)                    │
# │ X-Amz-Cf-Pop              │ HIO52-P2                                                                            │
# │ X-Amz-Cf-Id               │ _FuzWy_RbwvpH2AGqOdb9T9Jvbe8AODRQKbv5EkiNh6c_VK6wnVcBg==                            │
# ╰───────────────────────────┴─────────────────────────────────────────────────────────────────────────────────────╯
# bedrock threw context window overflow error
# Let me try to retrieve more specific information about Amazon Bedrock's models:
# Tool #4: http_request
# ╭────────────────────────────── 🚀 HTTP Request Preview: GET /bedrock/model-choice/ ──────────────────────────────╮
# │                                                                                                                 │
# │   Method    GET                                                                                                 │
# │   URL       https://aws.amazon.com/bedrock/model-choice/                                                        │
# │   Headers   {}                                                                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Sending request...
# ╭──────────────────────────────────────────── ✅ HTTP Response: 200  ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │     Status         200                                                                                          │
# │     URL            https://aws.amazon.com/bedrock/model-choice/                                                 │
# │     Content-Type   text/html;charset=utf-8                                                                      │
# │     Size           277,986 bytes (271.5 KB)                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                                  Response Headers
# ╭───────────────────────────┬─────────────────────────────────────────────────────────────────────────────────────╮
# │ Header                    │ Value                                                                               │
# ├───────────────────────────┼─────────────────────────────────────────────────────────────────────────────────────┤
# │ Content-Type              │ text/html;charset=utf-8                                                             │
# │ Transfer-Encoding         │ chunked                                                                             │
# │ Connection                │ keep-alive                                                                          │
# │ Date                      │ Sat, 29 Nov 2025 16:15:45 GMT                                                       │
# │ Set-Cookie                │ aws-priv=eyJ2IjoxLCJldSI6MCwic3QiOjB9; Version=1; Comment="Anonymous cookie for     │
# │                           │ privacy regulations"...                                                             │
# │ X-Content-Type-Options    │ nosniff                                                                             │
# │ Server                    │ Server                                                                              │
# │ X-Frame-Options           │ SAMEORIGIN                                                                          │
# │ X-XSS-Protection          │ 1; mode=block                                                                       │
# │ Strict-Transport-Security │ max-age=47304000; includeSubDomains                                                 │
# │ x-amz-id-1                │ 1121919B7FF647A48473                                                                │
# │ Last-Modified             │ Mon, 24 Nov 2025 22:48:06 GMT                                                       │
# │ vary                      │ accept-encoding                                                                     │
# │ Content-Encoding          │ gzip                                                                                │
# │ X-Cache                   │ Miss from cloudfront                                                                │
# │ Via                       │ 1.1 f94332f6513a4c7b3f2217e6b2ddc08c.cloudfront.net (CloudFront)                    │
# │ X-Amz-Cf-Pop              │ HIO52-P2                                                                            │
# │ X-Amz-Cf-Id               │ wQru4SjNoGrGC7_XtGiVR3_NTySDGrZfcyGhHQuFTiuXbXXm1QFmiQ==                            │
# ╰───────────────────────────┴─────────────────────────────────────────────────────────────────────────────────────╯
# bedrock threw context window overflow error
# # Amazon Bedrock: A Comprehensive Overview
#
# Amazon Bedrock is AWS's fully managed service for building and scaling generative AI applications using foundation models (FMs). Launched as a major player in AWS's AI offerings, it provides developers with a unified API to access high-performing foundation models from leading AI companies and Amazon itself.
#
# ## Core Features and Capabilities
#
# ### 1. Foundation Model Access
#
# Amazon Bedrock provides access to a wide range of foundation models from leading AI companies, including:
# - **Amazon's own models**: Amazon Titan and Amazon Nova
# - **Anthropic models**: Claude, Claude 3 family
# - **AI21 Labs models**: Jurassic models
# - **Cohere models**: Command and Embed models
# - **Meta models**: Llama 2
# - **Stability AI models**: Stable Diffusion
#
# This variety allows developers to choose the best model for their specific use case without being locked into a single provider.
#
# ### 2. Model Customization
#
# Amazon Bedrock offers several ways to customize foundation models:
#
# - **Fine-tuning**: Adapt models to specific tasks by providing training data to adjust a model's parameters
# - **Knowledge Bases**: Connect models to your own data sources through Retrieval Augmented Generation (RAG)
# - **Prompt Engineering**: Optimize inputs for better outputs
# - **Continued Pre-training**: Further training on domain-specific data for specialized knowledge
#
# ### 3. Production-Ready Infrastructure
#
# - **Serverless Architecture**: No infrastructure to manage
# - **Provisioned Throughput**: Reserve capacity for consistent performance and discounted rates
# - **Enterprise Security**: Built-in security, privacy, and compliance features
# - **Scalability**: Designed to handle production workloads at any scale
#
# ### 4. Security and Responsible AI
#
# - **Data Privacy**: Your data is never used to train models
# - **Guardrails**: Implement safeguards to prevent inappropriate or unwanted content
# - **Compliance**: HIPAA eligible and supports numerous compliance standards including ISO, SOC, CSA STAR Level 2, GDPR, and FedRAMP High
# - **Encryption**: Data encrypted in transit and at rest
#
# ### 5. Development Tools
#
# - **Interactive Playgrounds**: Text, image, and chat interfaces for experimentation
# - **Evaluation Tools**: Compare models and configurations to determine the best fit
# - **Unified API**: Consistent interface across different foundation models
# - **Integration with AWS Services**: Works with other AWS services for comprehensive AI solutions
#
# ### 6. Amazon Bedrock AgentCore
#
# AgentCore is a comprehensive agentic platform that helps developers accelerate AI agents into production with:
#
# - **AgentCore Gateway**: Enables agents to discover and securely connect to tools, data, and other agents
# - **AgentCore Memory**: Allows agents to retain both short-term and long-term memory with high accuracy
# - **AgentCore Runtime**: Secure deployment and scaling, with the longest session runtime in the industry for asynchronous workloads
# - **AgentCore Identity**: Seamless and secure agent authentication
# - **AgentCore Observability**: Monitoring tools to ensure reliable and secure agent operations
#
# ### 7. Performance Optimization
#
# - **Latency Optimization**: Features to reduce response times for better user experience
# - **Cost Optimization**: Various techniques including model distillation and intelligent prompt routing to reduce expenses while maintaining performance
# - **Model Evaluation**: Tools to assess model performance for your specific use cases
#
# ## Business Benefits
#
# 1. **Flexibility**: Choose from multiple model providers without lock-in
# 2. **Enterprise-grade Security**: Built-in security and privacy controls
# 3. **Cost Efficiency**: Serverless pricing model with optimization features
# 4. **Rapid Development**: Comprehensive tools to accelerate AI application development
# 5. **Scalability**: Production-ready infrastructure that scales with your needs
#
# ## Use Cases
#
# - **Content Generation**: Create blog posts, social media content, and marketing materials
# - **Virtual Assistants**: Build AI agents that can understand requests and take actions
# - **Document Processing**: Summarize long documents and extract insights
# - **Image Generation**: Create realistic images for various applications
# - **Workflow Automation**: Streamline operations across business functions
# - **Data Analysis**: Generate insights from complex datasets
#
# ## Getting Started
#
# To get started with Amazon Bedrock:
#
# 1. Familiarize yourself with the key terms and concepts
# 2. Review pricing information
# 3. Access the Amazon Bedrock console to experiment with models in the interactive playgrounds
# 4. Use the AWS SDK to integrate Amazon Bedrock into your applications
#
# ## Customer Success
#
# Many organizations have successfully implemented Amazon Bedrock for their AI initiatives. For example, Robinhood transformed into an AI-first financial innovator using Amazon Bedrock, scaling from 500 million to 5 billion tokens daily in just six months—while slashing AI costs by 80% and cutting development time in half.
#
# ## Conclusion
#
# Amazon Bedrock represents AWS's comprehensive offering in the generative AI space, providing a secure, flexible, and scalable platform for building AI applications. With access to multiple foundation models, customization capabilities, and enterprise-grade features, it enables organizations to leverage the power of generative AI while maintaining control over their data and applications.
#
# ---
#
# Sources:
# 1. AWS Official Website: https://aws.amazon.com/bedrock/
# 2. Amazon Bedrock Documentation: https://docs.aws.amazon.com/bedrock/latest/userguide/what-is-bedrock.html

# %% [markdown]
# Now we can wrap this agent as a tool. Allowing other agents to interact with it.
#
# ####  Best Practices for Agent as Tools
#
# When implementing the "Agents as Tools" pattern with Strands Agents:
#
# 1. Clear tool documentation: Write descriptive docstrings that explain the agent's expertise
# 2. Focused system prompts: Keep each specialized agent tightly focused on its domain
# 3. Proper response handling: Use consistent patterns to extract and format responses
# 4. Tool selection guidance: Give the orchestrator clear criteria for when to use each specialized agen

# %%
@tool
def research_assistant(query: str) -> str:
    """
    Process and respond to research-related queries.

    Args:
        query: A research question requiring factual information

    Returns:
        A detailed research answer with citations
    """
    try:
        # Strands agents makes it easy to create a specialized agent
        research_agent = Agent(
            model="us.anthropic.claude-3-7-sonnet-20250219-v1:0",
            system_prompt=RESEARCH_ASSISTANT_PROMPT,
            tools=[http_request]
        )

        # Call the agent and return its response
        response = research_agent(query)
        return str(response)
    except Exception as e:
        return f"Error in research assistant: {str(e)}"

# %% [markdown]
# Now lets follow the best practices and create `product_recommendation_assistant`, `trip_planning_assistant`, and `orchestrator` agent.

# %% [markdown]
# ### Product Recommendation Assistant

# %%
@tool
def product_recommendation_assistant(query: str) -> str:
    """
    Handle product recommendation queries by suggesting appropriate products.

    Args:
        query: A product inquiry with user preferences

    Returns:
        Personalized product recommendations with reasoning
    """
    try:
        product_agent = Agent(
            model="us.anthropic.claude-3-7-sonnet-20250219-v1:0",  # Optional: Specify the model ID
            system_prompt="""You are a specialized product recommendation assistant.
            Provide personalized product suggestions based on user preferences. Always cite your sources.""",
            tools=[http_request]
        )
        # Call the agent and return its response
        response = product_agent(query)

        return str(response)
    except Exception as e:
        return f"Error in product recommendation: {str(e)}"

# %%
product_recommendation_assistant("Product recommendations for flying cars")
# Out:
# # Flying Car Product Recommendations
#
# While true flying cars are still largely in development, there are several advanced personal aircraft and eVTOL (electric vertical takeoff and landing) vehicles that represent the closest current technology to flying cars.
#
# ## Current Options
#
# 1. **PAL-V Liberty** - A three-wheeled vehicle that converts between driving and flying modes. It's one of the first commercially available flying cars with deliveries beginning in select markets.
#    [Source: PAL-V official website]
#
# 2. **AeroMobil 4.0** - A Slovak hybrid car-aircraft with foldable wings, capable of transforming between modes in under 3 minutes.
#    [Source: AeroMobil company information]
#
# 3. **Terrafugia Transition** - A roadable aircraft that can fold its wings for road travel, though production has faced delays.
#    [Source: Terrafugia company updates]
#
# ## Pre-Order/Development Stage
#
# 1. **Alef Model A** - An electric flying car with a projected price of $300,000, currently accepting pre-orders.
#    [Source: Alef Aeronautics announcements]
#
# 2. **Jetson ONE** - A personal electric aerial vehicle with vertical take-off and landing capabilities.
#    [Source: Jetson Aero website]
#
# 3. **SkyDrive SD-03** - A Japanese eVTOL vehicle aiming for commercialization in the next few years.
#    [Source: SkyDrive Inc. press releases]
#
# Would you like more specific information about any of these options or are you looking for a particular type of flying vehicle?
# "# Flying Car Product Recommendations\n\nWhile true flying cars are still largely in development, there are several advanced personal aircraft and eVTOL (electric vertical takeoff and landing) vehicles that represent the closest current technology to flying cars.\n\n## Current Options\n\n1. **PAL-V Liberty** - A three-wheeled vehicle that converts between driving and flying modes. It's one of the first commercially available flying cars with deliveries beginning in select markets.\n   [Source: PAL-V official website]\n\n2. **AeroMobil 4.0** - A Slovak hybrid car-aircraft with foldable wings, capable of transforming between modes in under 3 minutes.\n   [Source: AeroMobil company information]\n\n3. **Terrafugia Transition** - A roadable aircraft that can fold its wings for road travel, though production has faced delays.\n   [Source: Terrafugia company updates]\n\n## Pre-Order/Development Stage\n\n1. **Alef Model A** - An electric flying car with a projected price of $300,000, currently accepting pre-orders.\n   [Source: Alef Aeronautics announcements]\n\n2. **Jetson ONE** - A personal electric aerial vehicle with vertical take-off and landing capabilities.\n   [Source: Jetson Aero website]\n\n3. **SkyDrive SD-03** - A Japanese eVTOL vehicle aiming for commercialization in the next few years.\n   [Source: SkyDrive Inc. press releases]\n\nWould you like more specific information about any of these options or are you looking for a particular type of flying vehicle?\n"

# %%
# What if we give agent tool to serach web and then try same!
product_recommendation_assistant("Product recommendations for flying cars")
# Out:
# I'd be happy to provide product recommendations for flying cars. As this is an emerging technology, let's check what options are currently available or in development. Let me search for the latest information on flying cars.
# Tool #1: http_request
# ╭───────────────────────────────────── 🚀 HTTP Request Preview: GET /search ──────────────────────────────────────╮
# │                                                                                                                 │
# │   Method    GET                                                                                                 │
# │   URL       https://www.google.com/search?q=latest+flying+car+models+2023                                       │
# │   Headers   {}                                                                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Sending request...
# ╭─────────────────────────────────────────── ✅ HTTP Response: 200 OK ────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │     Status         200 OK                                                                                       │
# │     URL            https://www.google.com/search?q=latest+flying+car+models+2023                                │
# │     Content-Type   text/html; charset=ISO-8859-1                                                                │
# │     Size           84,339 bytes (82.4 KB)                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                                  Response Headers
# ╭─────────────────────────┬───────────────────────────────────────────────────────────────────────────────────────╮
# │ Header                  │ Value                                                                                 │
# ├─────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────┤
# │ Content-Type            │ text/html; charset=ISO-8859-1                                                         │
# │ Content-Security-Policy │ object-src 'none';base-uri 'self';script-src 'nonce-jESGETWrVuDp4CjCzpvBwA'           │
# │                         │ 'strict-dynamic' 'report...                                                           │
# │ Accept-CH               │ Sec-CH-Prefers-Color-Scheme                                                           │
# │ P3P                     │ CP="This is not a P3P policy! See g.co/p3phelp for more info."                        │
# │ Content-Encoding        │ gzip                                                                                  │
# │ Date                    │ Sat, 29 Nov 2025 16:20:35 GMT                                                         │
# │ Server                  │ gws                                                                                   │
# │ X-XSS-Protection        │ 0                                                                                     │
# │ X-Frame-Options         │ SAMEORIGIN                                                                            │
# │ Expires                 │ Sat, 29 Nov 2025 16:20:35 GMT                                                         │
# │ Cache-Control           │ private                                                                               │
# │ Set-Cookie              │ AEC=AaJma5uTky37jEJncUihxrwzqRDapEKCr5wnER4oovxMJgT0zBGTQoMjgw; expires=Thu,          │
# │                         │ 28-May-2026 16:20:35 GM...                                                            │
# │ Alt-Svc                 │ h3=":443"; ma=2592000,h3-29=":443"; ma=2592000                                        │
# │ Transfer-Encoding       │ chunked                                                                               │
# ╰─────────────────────────┴───────────────────────────────────────────────────────────────────────────────────────╯
# Let me try a more specific search for flying car information from reliable sources.
# Tool #2: http_request
# ╭─ 🚀 HTTP Request Preview: GET /2023/05/16/flying-cars-closer-to-reality-as-faa-approves-test-flight-for-alefs-v─╮
# │                                                                                                                 │
# │   Method    GET                                                                                                 │
# │   URL       https://www.cnbc.com/2023/05/16/flying-cars-closer-to-reality-as-faa-approves-test-flight-for-al…   │
# │   Headers   {}                                                                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Sending request...
# ╭───────────────────────────────────────────── ❌ HTTP Response: 0  ──────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │     Status         403 Forbidden                                                                                │
# │     URL            https://www.cnbc.com/2023/05/16/flying-cars-closer-to-reality-as-faa-approves-test-flig…     │
# │     Content-Type   text/html                                                                                    │
# │     Size           521 bytes                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Let me try another source for flying car information:
# Tool #3: http_request
# ╭───────────────────────────────── 🚀 HTTP Request Preview: GET /wiki/Flying_car ─────────────────────────────────╮
# │                                                                                                                 │
# │   Method    GET                                                                                                 │
# │   URL       https://en.wikipedia.org/wiki/Flying_car                                                            │
# │   Headers   {}                                                                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Sending request...
# ╭───────────────────────────────────────────── ❌ HTTP Response: 0  ──────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │     Status         403 Forbidden                                                                                │
# │     URL            https://en.wikipedia.org/wiki/Flying_car                                                     │
# │     Content-Type   text/plain                                                                                   │
# │     Size           126 bytes                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Let me try another approach to find information about flying cars:
# Tool #4: http_request
# ╭─────────────────────────── 🚀 HTTP Request Preview: GET /transportation/flying-cars/ ───────────────────────────╮
# │                                                                                                                 │
# │   Method    GET                                                                                                 │
# │   URL       https://techcrunch.com/transportation/flying-cars/                                                  │
# │   Headers   {'User-Agent': 'Mozilla/5.0'}                                                                       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Sending request...
# ╭───────────────────────────────────────────── ❌ HTTP Response: 0  ──────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │     Status         404 Not Found                                                                                │
# │     URL            https://techcrunch.com/transportation/flying-cars/                                           │
# │     Content-Type   text/html; charset=UTF-8                                                                     │
# │     Size           172,682 bytes (168.6 KB)                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Let me try one more source to find information on flying cars:
# Tool #5: http_request
# ╭─────────────────────────── 🚀 HTTP Request Preview: GET /article/flying-cars-guide/ ────────────────────────────╮
# │                                                                                                                 │
# │   Method    GET                                                                                                 │
# │   URL       https://www.autoblog.com/article/flying-cars-guide/                                                 │
# │   Headers   {'User-Agent': 'Mozilla/5.0'}                                                                       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Sending request...
# ╭───────────────────────────────────────────── ❌ HTTP Response: 0  ──────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │     Status         403 Forbidden                                                                                │
# │     URL            https://www.autoblog.com/article/flying-cars-guide/                                          │
# │     Content-Type   text/html;charset=utf-8                                                                      │
# │     Size           772 bytes                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Based on the limited information I've been able to gather, I'll provide you with recommendations for flying cars, including the current state of development and some of the leading projects in this emerging industry.
#
# # Flying Car Recommendations: The Future Takes Flight
#
# ## Current State of Flying Cars
#
# Flying cars (also called electric vertical takeoff and landing vehicles or eVTOLs) are currently in various stages of development, with several companies making significant progress toward commercialization. While true commercial availability is still limited, many prototypes are undergoing testing and regulatory approval processes.
#
# ## Top Flying Car Companies and Models
#
# ### 1. **Alef Aeronautics Model A**
#    - **Status**: FAA-approved for test flights
#    - **Projected Price**: $300,000
#    - **Features**: Electric power, vertical takeoff and landing, transition to forward flight
#    - **Notes**: In 2023, Alef's Model A received special airworthiness certification from the FAA, marking a significant milestone toward commercial production. It resembles a conventional car but can take off vertically and transition to forward flight.
#
# ### 2. **Joby Aviation S4**
#    - **Status**: Advanced testing phase, FAA certification in progress
#    - **Projected Price**: Will likely operate as air taxi service rather than private ownership
#    - **Features**: Electric power, vertical takeoff and landing, 150-mile range, speeds up to 200 mph
#    - **Notes**: Joby acquired Uber Elevate and has backing from Toyota. The company aims to launch commercial air taxi services in the coming years.
#
# ### 3. **Lilium Jet**
#    - **Status**: Prototype testing
#    - **Projected Price**: Will operate as air taxi service
#    - **Features**: 36 electric jet engines mounted on tilting wings, 186-mile range
#    - **Notes**: The distinctive design uses numerous small electric jets rather than large rotors, potentially offering better efficiency and lower noise.
#
# ### 4. **AeroMobil 4.0**
#    - **Status**: Production plans announced
#    - **Projected Price**: $1.2-1.6 million
#    - **Features**: Hybrid design that functions as both car and aircraft, transforms between modes in under 3 minutes
#    - **Notes**: More traditional "flying car" design that can drive on roads and fly, rather than just an aircraft that can take off vertically.
#
# ### 5. **Klein Vision AirCar**
#    - **Status**: Completed test flights, received Certificate of Airworthiness from Slovak Transport Authority
#    - **Projected Price**: Expected around $600,000
#    - **Features**: Transforms from car to aircraft in 2-3 minutes, requires runway for takeoff
#    - **Notes**: Has successfully completed intercity flights in Slovakia.
#
# ### 6. **Terrafugia Transition**
#    - **Status**: FAA approval received, deliveries delayed
#    - **Projected Price**: $400,000
#    - **Features**: Folding wings, hybrid electric drive system, highway capable
#    - **Notes**: One of the earliest flying car projects to receive FAA approval as a Light Sport Aircraft.
#
# ### 7. **PAL-V Liberty**
#    - **Status**: Production-ready, European road certification completed
#    - **Projected Price**: $400,000-600,000
#    - **Features**: Three-wheeled design, gyrocopter flight system
#    - **Notes**: Uses a different approach with a gyrocopter design rather than fixed wings.
#
# ## Considerations When Evaluating Flying Cars
#
# 1. **Regulatory Approval**: Check if the model has FAA or equivalent certification for your region.
#
# 2. **Infrastructure Requirements**: Some models need runways while others can take off vertically from small spaces.
#
# 3. **Pilot Requirements**: Most current models require a pilot's license to operate.
#
# 4. **Range and Speed**: Consider typical journey distances when evaluating battery range.
#
# 5. **Safety Features**: Look for redundant systems, ballistic parachutes, and collision avoidance technology.
#
# 6. **Operating Costs**: Beyond the purchase price, consider maintenance, energy costs, insurance, and storage.
#
# ## The Reality Check
#
# It's important to note that while flying cars are advancing rapidly, most are still not available for immediate consumer purchase. Many companies are focusing on air taxi services rather than private ownership initially, due to regulatory complexities and infrastructure limitations.
#
# If you're interested in this technology, you might consider:
# - Joining waiting lists for models nearing production
# - Investing in companies developing this technology
# - Following developments in urban air mobility infrastructure
# - Getting your pilot's license to be prepared when these vehicles become available
#
# ## Conclusion
#
# Flying cars are transitioning from science fiction to reality, but the industry is still in its early stages. The most advanced projects are focusing on air taxi services rather than personal ownership in the immediate term, though several companies are working toward consumer models. For those eager to embrace this technology, staying informed about regulatory developments and company progress is key to making informed decisions when these vehicles eventually reach the market.
# 'Based on the limited information I\'ve been able to gather, I\'ll provide you with recommendations for flying cars, including the current state of development and some of the leading projects in this emerging industry.\n\n# Flying Car Recommendations: The Future Takes Flight\n\n## Current State of Flying Cars\n\nFlying cars (also called electric vertical takeoff and landing vehicles or eVTOLs) are currently in various stages of development, with several companies making significant progress toward commercialization. While true commercial availability is still limited, many prototypes are undergoing testing and regulatory approval processes.\n\n## Top Flying Car Companies and Models\n\n### 1. **Alef Aeronautics Model A**\n   - **Status**: FAA-approved for test flights\n   - **Projected Price**: $300,000\n   - **Features**: Electric power, vertical takeoff and landing, transition to forward flight\n   - **Notes**: In 2023, Alef\'s Model A received special airworthiness certification from the FAA, marking a significant milestone toward commercial production. It resembles a conventional car but can take off vertically and transition to forward flight.\n\n### 2. **Joby Aviation S4**\n   - **Status**: Advanced testing phase, FAA certification in progress\n   - **Projected Price**: Will likely operate as air taxi service rather than private ownership\n   - **Features**: Electric power, vertical takeoff and landing, 150-mile range, speeds up to 200 mph\n   - **Notes**: Joby acquired Uber Elevate and has backing from Toyota. The company aims to launch commercial air taxi services in the coming years.\n\n### 3. **Lilium Jet**\n   - **Status**: Prototype testing\n   - **Projected Price**: Will operate as air taxi service\n   - **Features**: 36 electric jet engines mounted on tilting wings, 186-mile range\n   - **Notes**: The distinctive design uses numerous small electric jets rather than large rotors, potentially offering better efficiency and lower noise.\n\n### 4. **AeroMobil 4.0**\n   - **Status**: Production plans announced\n   - **Projected Price**: $1.2-1.6 million\n   - **Features**: Hybrid design that functions as both car and aircraft, transforms between modes in under 3 minutes\n   - **Notes**: More traditional "flying car" design that can drive on roads and fly, rather than just an aircraft that can take off vertically.\n\n### 5. **Klein Vision AirCar**\n   - **Status**: Completed test flights, received Certificate of Airworthiness from Slovak Transport Authority\n   - **Projected Price**: Expected around $600,000\n   - **Features**: Transforms from car to aircraft in 2-3 minutes, requires runway for takeoff\n   - **Notes**: Has successfully completed intercity flights in Slovakia.\n\n### 6. **Terrafugia Transition**\n   - **Status**: FAA approval received, deliveries delayed\n   - **Projected Price**: $400,000\n   - **Features**: Folding wings, hybrid electric drive system, highway capable\n   - **Notes**: One of the earliest flying car projects to receive FAA approval as a Light Sport Aircraft.\n\n### 7. **PAL-V Liberty**\n   - **Status**: Production-ready, European road certification completed\n   - **Projected Price**: $400,000-600,000\n   - **Features**: Three-wheeled design, gyrocopter flight system\n   - **Notes**: Uses a different approach with a gyrocopter design rather than fixed wings.\n\n## Considerations When Evaluating Flying Cars\n\n1. **Regulatory Approval**: Check if the model has FAA or equivalent certification for your region.\n\n2. **Infrastructure Requirements**: Some models need runways while others can take off vertically from small spaces.\n\n3. **Pilot Requirements**: Most current models require a pilot\'s license to operate.\n\n4. **Range and Speed**: Consider typical journey distances when evaluating battery range.\n\n5. **Safety Features**: Look for redundant systems, ballistic parachutes, and collision avoidance technology.\n\n6. **Operating Costs**: Beyond the purchase price, consider maintenanc ...

# %% [markdown]
# ### Trip Planning Assistant

# %%
@tool
def trip_planning_assistant(query: str) -> str:
    """
    Create travel itineraries and provide travel advice.

    Args:
        query: A travel planning request with destination and preferences

    Returns:
        A detailed travel itinerary or travel advice
    """
    try:
        travel_agent = Agent(
            model="us.anthropic.claude-3-7-sonnet-20250219-v1:0",  # Optional: Specify the model ID
            system_prompt="""You are a specialized travel planning assistant.
            Create detailed travel itineraries based on user preferences.""",
        )
        # Call the agent and return its response
        response = travel_agent(query)

        return str(response)
    except Exception as e:
        return f"Error in trip planning: {str(e)}"

# %% [markdown]
# ### Orchestrator Agent

# %%
# Define orchestrator system prompt with clear tool selection guidance
MAIN_SYSTEM_PROMPT = """
You are an assistant that routes queries to specialized agents:
- For research questions and factual information → Use the research_assistant tool
- For product recommendations and shopping advice → Use the product_recommendation_assistant tool
- For travel planning and itineraries → Use the trip_planning_assistant tool
- For simple questions not requiring specialized knowledge → Answer directly

Always select the most appropriate tool based on the user's query.
"""

# %%
# Strands Agents allows easy integration of agent tools
orchestrator = Agent(
    model="us.anthropic.claude-3-7-sonnet-20250219-v1:0",  # Optional: Specify the model ID
    system_prompt=MAIN_SYSTEM_PROMPT,
    tools=[
        research_assistant,
        product_recommendation_assistant,
        trip_planning_assistant,
        file_write,
    ],
)

# %%
# Example: E-commerce Customer Service System
customer_query = (
    "I'm looking for hiking boots. Write the final response to current directory."
)

os.environ["BYPASS_TOOL_CONSENT"] = "true"

# The orchestrator automatically determines this requires multiple specialized agents
response = orchestrator(customer_query)
# Out:
# I'd be happy to help you find hiking boots. This is a product recommendation request, so I'll use the specialized product recommendation tool to provide you with some good options.
#
# Could you provide a bit more information about your preferences for hiking boots? For example:
# - What type of hiking do you plan to do (day hikes, backpacking, mountaineering)?
# - Do you have specific features you're looking for (waterproof, ankle support, etc.)?
# - Any brand preferences or price range?
# - Men's or women's boots?
#
# This will help me give you more personalized recommendations. Also, I notice you'd like the response saved to a file - I can certainly do that once we have the recommendations.

# %% [markdown]
# Lets look at the messages of the orchestrator. Here you can see the agent decided to use the sub-agent as tool

# %%
orchestrator.messages
# Out:
# [{'role': 'user',
#   'content': [{'text': "I'm looking for hiking boots. Write the final response to current directory."}]},
#  {'role': 'assistant',
#   'content': [{'text': "I'd be happy to help you find hiking boots. This is a product recommendation request, so I'll use the specialized product recommendation tool to provide you with some good options. \n\nCould you provide a bit more information about your preferences for hiking boots? For example:\n- What type of hiking do you plan to do (day hikes, backpacking, mountaineering)?\n- Do you have specific features you're looking for (waterproof, ankle support, etc.)?\n- Any brand preferences or price range?\n- Men's or women's boots?\n\nThis will help me give you more personalized recommendations. Also, I notice you'd like the response saved to a file - I can certainly do that once we have the recommendations."}]}]

# %%
customer_query = "Can you help me plan my trip to Polynasia"

response = orchestrator(customer_query)
# Out:
# I'd be happy to help you plan a trip to Polynesia! This is a travel planning request, so I'll use the specialized travel planning tool to assist you with creating an itinerary for your Polynesian adventure.
# Tool #1: trip_planning_assistant
# # Polynesia Travel Itinerary
#
# ## Overview
# French Polynesia offers a stunning paradise of 118 islands spread across five archipelagos in the South Pacific. With crystal clear waters, overwater bungalows, and rich Polynesian culture, this destination promises an unforgettable tropical experience.
#
# ## Recommended Islands
#
# ### 1. Tahiti (3 nights)
# The gateway to French Polynesia and largest island.
#
# ### 2. Bora Bora (4-5 nights)
# The iconic island known for luxury and stunning lagoons.
#
# ### 3. Moorea (3-4 nights)
# Known as Tahiti's sister island with dramatic landscapes.
#
# ### 4. Huahine (2-3 nights)
# For authentic Polynesian culture and fewer tourists.
#
# ### 5. Rangiroa or Fakarava (3 nights)
# For world-class diving and snorkeling in massive atolls.
#
# ## Sample 14-Day Itinerary
#
# ### Days 1-3: Tahiti
# * **Accommodations:** InterContinental Tahiti or Tahiti Pearl Beach Resort
# * **Activities:**
#   * Explore Papeete markets and waterfront
#   * Visit Point Venus and Arahoho Blowhole
#   * Hike to Fautaua Waterfall
#   * Take a 4x4 safari to the island's interior
#
# ### Days 4-7: Bora Bora
# * **Accommodations:** Four Seasons, St. Regis, or InterContinental (overwater bungalow)
# * **Activities:**
#   * Lagoon tour with shark and ray feeding
#   * Mount Otemanu hike or 4x4 tour
#   * Coral reef snorkeling
#   * Jet ski tour around the island
#   * Sunset sailing cruise
#
# ### Days 8-11: Moorea
# * **Accommodations:** Hilton Moorea or Sofitel Moorea
# * **Activities:**
#   * Belvedere Lookout for panoramic views
#   * Swim with dolphins at the Moorea Dolphin Center
#   * ATV tour of pineapple plantations
#   * Snorkeling at Lagoonarium
#   * Visit Tiki Village for traditional dance show
#
# ### Days 12-14: Huahine
# * **Accommodations:** Royal Huahine or Hotel Le Mahana
# * **Activities:**
#   * Visit ancient marae (temples)
#   * Tour the vanilla plantations
#   * Pearl farm visit
#   * Explore the small villages around the island
#   * Relax on beaches with fewer tourists
#
# ## Practical Information
#
# ### Best Time to Visit
# * **May to October:** Dry season with pleasant temperatures (70-85°F)
# * **November to April:** Rainy season, more humid but less crowded
#
# ### Getting There & Around
# * International flights arrive at Faa'a International Airport in Tahiti
# * Air Tahiti provides inter-island flights
# * Ferry service available between Tahiti and Moorea
# * On islands: car rentals, scooters, bikes, or guided tours
#
# ### Budget Considerations
# * **Luxury:** $700-1,500+ per day
# * **Mid-range:** $400-700 per day
# * **Budget:** $200-400 per day (guesthouses, pensions)
#
# ### Travel Tips
# * **Currency:** French Pacific Franc (XPF)
# * **Language:** French and Tahitian (English widely spoken at resorts)
# * **Electricity:** 110V/220V, French-style outlets
# * **Tipping:** Not expected but appreciated for exceptional service
# * **Pack reef-safe sunscreen** to protect the coral ecosystems
# * Consider "island hopping" passes from Air Tahiti for cost savings
# * Book accommodations well in advance, especially overwater bungalows
# * Many resorts offer all-inclusive packages worth considering
# * Bring insect repellent for evenings
#
# ### Cultural Etiquette
# * Dress modestly when visiting villages (cover shoulders and knees)
# * Remove shoes when entering someone's home
# * Learn a few basic Tahitian phrases (Ia ora na = hello)
# * Ask permission before photographing locals
#
# Would you like more specific information about any particular aspect of your Polynesian adventure?# Polynesia Travel Itinerary
#
# ## Overview
# French Polynesia offers a stunning paradise of 118 islands spread across five archipelagos in the South Pacific. With crystal clear waters, overwater bungalows, and rich Polynesian culture, this destination promises an unforgettable tropical experience.
#
# ## Recommended Islands
#
# ### 1. Tahiti (3 nights)
# The gateway to French Polynesia and largest island.
#
# ### 2. Bora Bora (4-5 nights)
# The iconic island known for luxury and stunning lagoons.
#
# ### 3. Moorea (3-4 nights)
# Known as Tahiti's sister island with dramatic landscapes.
#
# ### 4. Huahine (2-3 nights)
# For authentic Polynesian culture and fewer tourists.
#
# ### 5. Rangiroa or Fakarava (3 nights)
# For world-class diving and snorkeling in massive atolls.
#
# ## Sample 14-Day Itinerary
#
# ### Days 1-3: Tahiti
# * **Accommodations:** InterContinental Tahiti or Tahiti Pearl Beach Resort
# * **Activities:**
#   * Explore Papeete markets and waterfront
#   * Visit Point Venus and Arahoho Blowhole
#   * Hike to Fautaua Waterfall
#   * Take a 4x4 safari to the island's interior
#
# ### Days 4-7: Bora Bora
# * **Accommodations:** Four Seasons, St. Regis, or InterContinental (overwater bungalow)
# * **Activities:**
#   * Lagoon tour with shark and ray feeding
#   * Mount Otemanu hike or 4x4 tour
#   * Coral reef snorkeling
#   * Jet ski tour around the island
#   * Sunset sailing cruise
#
# ### Days 8-11: Moorea
# * **Accommodations:** Hilton Moorea or Sofitel Moorea
# * **Activities:**
#   * Belvedere Lookout for panoramic views
#   * Swim with dolphins at the Moorea Dolphin Center
#   * ATV tour of pineapple plantations
#   * Snorkeling at Lagoonarium
#   * Visit Tiki Village for traditional dance show
#
# ### Days 12-14: Huahine
# * **Accommodations:** Royal Huahine or Hotel Le Mahana
# * **Activities:**
#   * Visit ancient marae (temples)
#   * Tour the vanilla plantations
#   * Pearl farm visit
#   * Explore the small villages around the island
#   * Relax on beaches with fewer tourists
#
# ## Practical Information
#
# ### Best Time to Visit
# * **May to October:** Dry season with pleasant temperatures (70-85°F)
# * **November to April:** Rainy season, more humid but less crowded
#
# ### Getting There & Around
# * International flights arrive at Faa'a International Airport in Tahiti
# * Air Tahiti provides inter-island flights
# * Ferry service available between Tahiti and Moorea
# * On islands: car rentals, scooters, bikes, or guided tours
#
# ### Budget Considerations
# * **Luxury:** $700-1,500+ per day
# * **Mid-range:** $400-700 per day
# * **Budget:** $200-400 per day (guesthouses, pensions)
#
# ### Travel Tips
# * **Currency:** French Pacific Franc (XPF)
# * **Language:** French and Tahitian (English widely spoken at resorts)
# * **Electricity:** 110V/220V, French-style outlets
# * **Tipping:** Not expected but appreciated for exceptional service
# * **Pack reef-safe sunscreen** to protect the coral ecosystems
# * Consider "island hopping" passes from Air Tahiti for cost savings
# * Book accommodations well in advance, especially overwater bungalows
# * Many resorts offer all-inclusive packages worth considering
# * Bring insect repellent for evenings
#
# ### Cultural Etiquette
# * Dress modestly when visiting villages (cover shoulders and knees)
# * Remove shoes when entering someone's home
# * Learn a few basic Tahitian phrases (Ia ora na = hello)
# * Ask permission before photographing locals
#
# Would you like me to save this itinerary to a file for you? Or would you like more specific information about any particular aspect of your Polynesian adventure?

# %%
orchestrator.messages
# Out:
# [{'role': 'user',
#   'content': [{'text': "I'm looking for hiking boots. Write the final response to current directory."}]},
#  {'role': 'assistant',
#   'content': [{'text': "I'd be happy to help you find hiking boots. This is a product recommendation request, so I'll use the specialized product recommendation tool to provide you with some good options. \n\nCould you provide a bit more information about your preferences for hiking boots? For example:\n- What type of hiking do you plan to do (day hikes, backpacking, mountaineering)?\n- Do you have specific features you're looking for (waterproof, ankle support, etc.)?\n- Any brand preferences or price range?\n- Men's or women's boots?\n\nThis will help me give you more personalized recommendations. Also, I notice you'd like the response saved to a file - I can certainly do that once we have the recommendations."}]},
#  {'role': 'user',
#   'content': [{'text': 'Can you help me plan my trip to Polynasia'}]},
#  {'role': 'assistant',
#   'content': [{'text': "I'd be happy to help you plan a trip to Polynesia! This is a travel planning request, so I'll use the specialized travel planning tool to assist you with creating an itinerary for your Polynesian adventure."},
#    {'toolUse': {'toolUseId': 'tooluse_cIghuVhgQo68U3F7-c5YXQ',
#      'name': 'trip_planning_assistant',
#      'input': {'query': 'Help plan a trip to Polynesia, including suggestions for islands to visit, activities, accommodations, and travel tips'}}}]},
#  {'role': 'user',
#   'content': [{'toolResult': {'toolUseId': 'tooluse_cIghuVhgQo68U3F7-c5YXQ',
#      'status': 'success',
#      'content': [{'text': '# Polynesia Travel Itinerary\n\n## Overview\nFrench Polynesia offers a stunning paradise of 118 islands spread across five archipelagos in the South Pacific. With crystal clear waters, overwater bungalows, and rich Polynesian culture, this destination promises an unforgettable tropical experience.\n\n## Recommended Islands\n\n### 1. Tahiti (3 nights)\nThe gateway to French Polynesia and largest island.\n   \n### 2. Bora Bora (4-5 nights)\nThe iconic island known for luxury and stunning lagoons.\n\n### 3. Moorea (3-4 nights)\nKnown as Tahiti\'s sister island with dramatic landscapes.\n\n### 4. Huahine (2-3 nights)\nFor authentic Polynesian culture and fewer tourists.\n\n### 5. Rangiroa or Fakarava (3 nights)\nFor world-class diving and snorkeling in massive atolls.\n\n## Sample 14-Day Itinerary\n\n### Days 1-3: Tahiti\n* **Accommodations:** InterContinental Tahiti or Tahiti Pearl Beach Resort\n* **Activities:**\n  * Explore Papeete markets and waterfront\n  * Visit Point Venus and Arahoho Blowhole\n  * Hike to Fautaua Waterfall\n  * Take a 4x4 safari to the island\'s interior\n\n### Days 4-7: Bora Bora\n* **Accommodations:** Four Seasons, St. Regis, or InterContinental (overwater bungalow)\n* **Activities:**\n  * Lagoon tour with shark and ray feeding\n  * Mount Otemanu hike or 4x4 tour\n  * Coral reef snorkeling\n  * Jet ski tour around the island\n  * Sunset sailing cruise\n\n### Days 8-11: Moorea\n* **Accommodations:** Hilton Moorea or Sofitel Moorea\n* **Activities:**\n  * Belvedere Lookout for panoramic views\n  * Swim with dolphins at the Moorea Dolphin Center\n  * ATV tour of pineapple plantations\n  * Snorkeling at Lagoonarium\n  * Visit Tiki Village for traditional dance show\n\n### Days 12-14: Huahine\n* **Accommodations:** Royal Huahine or Hotel Le Mahana\n* **Activities:**\n  * Visit ancient marae (temples)\n  * Tour the vanilla plantations\n  * Pearl farm visit\n  * Explore the small villages around the island\n  * Relax on beaches with fewer tourists\n\n## Practical Information\n\n### Best Time to Visit\n* **May to October:** Dry season with pleasant temperatures (70-85°F)\n* **November to April:** Rainy season, more humid but less crowded\n\n### Getting There & Around\n* International flights arrive at Faa\'a International Airport in Tahiti\n* Air Tahiti provides inter-island flights\n* Ferry service available between Tahiti and Moorea\n* On islands: car rentals, scooters, bikes, or guided tours\n\n### Budget Considerations\n* **Luxury:** $700-1,500+ per day\n* **Mid-range:** $400-700 per day\n* **Budget:** $200-400 per day (guesthouses, pensions)\n\n### Travel Tips\n* **Currency:** French Pacific Franc (XPF)\n* **Language:** French and Tahitian (English widely spoken at resorts)\n* **Electricity:** 110V/220V, French-style outlets\n* **Tipping:** Not expected but appreciated for exceptional service\n* **Pack reef-safe sunscreen** to protect the coral ecosystems\n* Consider "island hopping" passes from Air Tahiti for cost savings\n* Book accommodations well in advance, especially overwater bungalows\n* Many resorts offer all-inclusive packages worth considering\n* Bring insect repellent for evenings\n\n### Cultural Etiquette\n* Dress modestly when visiting villages (cover shoulders and knees)\n* Remove shoes when entering someone\'s home\n* Learn a few basic Tahitian phrases (Ia ora na = hello)\n* Ask permission before photographing locals\n\nWould you like more specific information about any particular aspect of your Polynesian adventure?\n'}]}}]},
#  {'role': 'assistant',
#   'content': [{'text': '# Polynesia Travel Itinerary\n\n## Overview\nFrench Polynesia offers a stunning paradise of 118 islands spread across five archipelagos in the South Pacific. With crystal clear waters, overwater bungalows, and rich Polynesian culture, this destination promises an unforgettable tropical experience.\n\n## Recommended Islands\n\n### 1. Tahiti (3 nights)\nThe gateway to French Polynesia and largest island.\n   \n### 2. Bora Bora (4-5 nights)\nThe iconic island known for luxury and stunning lagoons.\n\n### 3. Moorea (3-4 nights)\nKnown as Tahiti\'s sister island with dramatic landscapes.\n\n### 4. Huahine (2-3 nights)\nFor authentic Polynesian culture and fewer tourists.\n\n### 5. Rangiroa or Fakarava (3 nights)\nFor world-class diving and snorkeling in massive atolls.\n\n## Sample 14-Day Itinerary\n\n### Days 1-3: Tahiti\n* **Accommodations:** InterContinental Tahiti or Tahiti Pearl Beach Resort\n* **Activities:**\n  * Explore Papeete markets and waterfront\n  * Visit Point Venus and Arahoho Blowhole\n  * Hike to Fautaua Waterfall\n  * Take a 4x4 safari to the island\'s interior\n\n### Days 4-7: Bora Bora\n* **Accommodations:** Four Seasons, St. Regis, or InterContinental (overwater bungalow)\n* **Activities:**\n  * Lagoon tour with shark and ray feeding\n  * Mount Otemanu hike or 4x4 tour\n  * Coral reef snorkeling\n  * Jet ski tour around the island\n  * Sunset sailing cruise\n\n### Days 8-11: Moorea\n* **Accommodations:** Hilton Moorea or Sofitel Moorea\n* **Activities:**\n  * Belvedere Lookout for panoramic views\n  * Swim with dolphins at the Moorea Dolphin Center\n  * ATV tour of pineapple plantations\n  * Snorkeling at Lagoonarium\n  * Visit Tiki Village for traditional dance show\n\n### Days 12-14: Huahine\n* **Accommodations:** Royal Huahine or Hotel Le Mahana\n* **Activities:**\n  * Visit ancient marae (temples)\n  * Tour the vanilla plantations\n  * Pearl farm visit\n  * Explore the small villages around the island\n  * Relax on beaches with fewer tourists\n\n## Practical Information\n\n### Best Time to Visit\n* **May to October:** Dry season with pleasant temperatures (70-85°F)\n* **November to April:** Rainy season, more humid but less crowded\n\n### Getting There & Around\n* International flights arrive at Faa\'a International Airport in Tahiti\n* Air Tahiti provides inter-island flights\n* Ferry service available between Tahiti and Moorea\n* On islands: car rentals, scooters, bikes, or guided tours\n\n### Budget Considerations\n* **Luxury:** $700-1,500+ per day\n* **Mid-range:** $400-700 per day\n* **Budget:** $200-400 per day (guesthouses, pensions)\n\n### Travel Tips\n* **Currency:** French Pacific Franc (XPF)\n* **Language:** French and Tahitian (English widely spoken at resorts)\n* **Electricity:** 110V/220V, French-style outlets\n* **Tipping:** Not expected but appreciated for exceptional service\n* **Pack reef-safe sunscreen** to protect the coral ecosystems\n* Consider "island hopping" passes from Air Tahiti for cost savings\n* Book accommodations well in advance, especially overwater bungalows\n* Many resorts offer all-inclusive packages worth considering\n* Bring insect repellent for evenings\n\n### Cultural Etiquette\n* Dress modestly when visiting villages (cover shoulders and knees)\n* Remove shoes when entering someone\'s home\n* Learn a few basic Tahitian phrases (Ia ora na = hello)\n* Ask permission before photographing locals\n\nWould you like me to save this itinerary to a file for you? Or would you like more specific information about any particular aspect of your Polynesian adventure?'}]}]

# %% [markdown]
# ### Calling multiple agents

# %%
orchestrator.messages = []

# %%
query = "Can you do a research on spain? Also help me plan a 7 day trip with approximate total cost of the trip."

orchestrator(query)
# Out:
# I'll help you with both research on Spain and a 7-day trip itinerary with cost estimates. Let me handle these requests separately.
#
# First, let me research Spain for you:
# Tool #2: research_assistant
# I'd be happy to research information about Spain for you. I'll use the http_request tool to gather comprehensive information about Spain's history, culture, geography, economy, and major attractions.
# Tool #1: http_request
# ╭───────────────────────── 🚀 HTTP Request Preview: GET /api/rest_v1/page/summary/Spain ──────────────────────────╮
# │                                                                                                                 │
# │   Method    GET                                                                                                 │
# │   URL       https://en.wikipedia.org/api/rest_v1/page/summary/Spain                                             │
# │   Headers   {}                                                                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Sending request...
# ╭───────────────────────────────────────────── ❌ HTTP Response: 0  ──────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │     Status         403 Forbidden                                                                                │
# │     URL            https://en.wikipedia.org/api/rest_v1/page/summary/Spain                                      │
# │     Content-Type   text/plain                                                                                   │
# │     Size           126 bytes                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# I need to set appropriate headers for this request. Let me try again with a proper user agent:
# Tool #2: http_request
# ╭───────────────────────── 🚀 HTTP Request Preview: GET /api/rest_v1/page/summary/Spain ──────────────────────────╮
# │                                                                                                                 │
# │   Method    GET                                                                                                 │
# │   URL       https://en.wikipedia.org/api/rest_v1/page/summary/Spain                                             │
# │   Headers   {'User-Agent': 'ResearchAssistantBot/1.0'}                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Sending request...
# ╭─────────────────────────────────────────── ✅ HTTP Response: 200 OK ────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │     Status         200 OK                                                                                       │
# │     URL            https://en.wikipedia.org/api/rest_v1/page/summary/Spain                                      │
# │     Content-Type   application/json; charset=utf-8;                                                             │
# │                    profile="https://www.mediawiki.org/wiki/Specs/Summary/1.5.0"                                 │
# │     Size           3,175 bytes (3.1 KB)                                                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                                  Response Headers
# ╭───────────────────────────────┬─────────────────────────────────────────────────────────────────────────────────╮
# │ Header                        │ Value                                                                           │
# ├───────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────┤
# │ content-security-policy       │ default-src 'none'; frame-ancestors 'none'                                      │
# │ x-content-security-policy     │ default-src 'none'; frame-ancestors 'none'                                      │
# │ x-webkit-csp                  │ default-src 'none'; frame-ancestors 'none'                                      │
# │ cache-control                 │ s-maxage=1209600, max-age=300                                                   │
# │ content-language              │ en                                                                              │
# │ content-type                  │ application/json; charset=utf-8;                                                │
# │                               │ profile="https://www.mediawiki.org/wiki/Specs/Summary/1.5.0"                    │
# │ date                          │ Sat, 29 Nov 2025 05:46:37 GMT                                                   │
# │ server                        │ production-tls                                                                  │
# │ access-control-allow-origin   │ *                                                                               │
# │ access-control-allow-methods  │ GET,HEAD                                                                        │
# │ access-control-allow-headers  │ accept, content-type, content-length, cache-control, accept-language,           │
# │                               │ api-user-agent, if-match, if-m...                                               │
# │ access-control-expose-headers │ etag                                                                            │
# │ x-content-type-options        │ nosniff                                                                         │
# │ x-frame-options               │ SAMEORIGIN                                                                      │
# │ referrer-policy               │ origin-when-cross-origin                                                        │
# │ x-xss-protection              │ 1; mode=block                                                                   │
# │ etag                          │ W/"1324713792/baac3e00-cce6-11f0-8bff-10cad6f5c23b"                             │
# │ content-encoding              │ gzip                                                                            │
# │ age                           │ 38343                                                                           │
# │ accept-ranges                 │ bytes                                                                           │
# │ vary                          │ x-restbase-compat, Accept-Encoding                                              │
# │ x-cache                       │ cp4041 miss, cp4041 hit/88                                                      │
# │ x-cache-status                │ hit-front                                                                       │
# │ server-timing                 │ cache;desc="hit-front", host;desc="cp4041"                                      │
# │ strict-transport-security     │ max-age=106384710; includeSubDomains; preload                                   │
# │ report-to                     │ { "group": "wm_nel", "max_age": 604800, "endpoints": [{ "url":                  │
# │                               │ "https://intake-logging.wikimedia.org...                                        │
# │ nel                           │ { "report_to": "wm_nel", "max_age": 604800, "failure_fraction": 0.05,           │
# │                               │ "success_fraction": 0.0}                                                        │
# │ set-cookie                    │ WMF-Last-Access=29-Nov-2025;Path=/;HttpOnly;secure;Expires=Wed, 31 Dec 2025     │
# │                               │ 12:00:00 GMT, WMF-Last-A...                                                     │
# │ x-client-ip                   │ 54.203.17.143                                                                   │
# │ content-length                │ 1026                                                                            │
# │ x-request-id                  │ 40ca449c-885a-46e5-9033-668b179a8b23                                            │
# │ x-analytics                   │                                                                                 │
# ╰───────────────────────────────┴─────────────────────────────────────────────────────────────────────────────────╯
# Now let me gather more detailed information about Spain's history:
# Tool #3: http_request
# ╭──────────────────── 🚀 HTTP Request Preview: GET /api/rest_v1/page/summary/History_of_Spain ────────────────────╮
# │                                                                                                                 │
# │   Method    GET                                                                                                 │
# │   URL       https://en.wikipedia.org/api/rest_v1/page/summary/History_of_Spain                                  │
# │   Headers   {'User-Agent': 'ResearchAssistantBot/1.0'}                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Sending request...
# ╭─────────────────────────────────────────── ✅ HTTP Response: 200 OK ────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │     Status         200 OK                                                                                       │
# │     URL            https://en.wikipedia.org/api/rest_v1/page/summary/History_of_Spain                           │
# │     Content-Type   application/json; charset=utf-8;                                                             │
# │                    profile="https://www.mediawiki.org/wiki/Specs/Summary/1.5.0"                                 │
# │     Size           2,677 bytes (2.6 KB)                                                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                                  Response Headers
# ╭───────────────────────────────┬─────────────────────────────────────────────────────────────────────────────────╮
# │ Header                        │ Value                                                                           │
# ├───────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────┤
# │ content-security-policy       │ default-src 'none'; frame-ancestors 'none'                                      │
# │ x-content-security-policy     │ default-src 'none'; frame-ancestors 'none'                                      │
# │ x-webkit-csp                  │ default-src 'none'; frame-ancestors 'none'                                      │
# │ cache-control                 │ s-maxage=1209600, max-age=300                                                   │
# │ content-language              │ en                                                                              │
# │ content-type                  │ application/json; charset=utf-8;                                                │
# │                               │ profile="https://www.mediawiki.org/wiki/Specs/Summary/1.5.0"                    │
# │ date                          │ Sat, 29 Nov 2025 16:25:43 GMT                                                   │
# │ server                        │ production-tls                                                                  │
# │ access-control-allow-origin   │ *                                                                               │
# │ access-control-allow-methods  │ GET,HEAD                                                                        │
# │ access-control-allow-headers  │ accept, content-type, content-length, cache-control, accept-language,           │
# │                               │ api-user-agent, if-match, if-m...                                               │
# │ access-control-expose-headers │ etag                                                                            │
# │ x-content-type-options        │ nosniff                                                                         │
# │ x-frame-options               │ SAMEORIGIN                                                                      │
# │ referrer-policy               │ origin-when-cross-origin                                                        │
# │ x-xss-protection              │ 1; mode=block                                                                   │
# │ etag                          │ W/"1324590740/d1158c00-cce6-11f0-93dc-0edb05350050"                             │
# │ content-encoding              │ gzip                                                                            │
# │ age                           │ 0                                                                               │
# │ accept-ranges                 │ bytes                                                                           │
# │ vary                          │ Accept-Language, x-restbase-compat, Accept-Encoding                             │
# │ x-cache                       │ cp4041 miss, cp4041 miss                                                        │
# │ x-cache-status                │ miss                                                                            │
# │ server-timing                 │ cache;desc="miss", host;desc="cp4041"                                           │
# │ strict-transport-security     │ max-age=106384710; includeSubDomains; preload                                   │
# │ report-to                     │ { "group": "wm_nel", "max_age": 604800, "endpoints": [{ "url":                  │
# │                               │ "https://intake-logging.wikimedia.org...                                        │
# │ nel                           │ { "report_to": "wm_nel", "max_age": 604800, "failure_fraction": 0.05,           │
# │                               │ "success_fraction": 0.0}                                                        │
# │ x-client-ip                   │ 54.203.17.143                                                                   │
# │ set-cookie                    │ WMF-Uniq=N9nWDAc1riiaNWVMbSvTkwK6AAEBAFvd5ivCjC7JoFSrV8gEc6BEQY-oMwZFMtx3;Doma… │
# │ content-length                │ 840                                                                             │
# │ x-request-id                  │ 55cededa-934f-4464-81e5-2bef583b794c                                            │
# │ x-analytics                   │                                                                                 │
# ╰───────────────────────────────┴─────────────────────────────────────────────────────────────────────────────────╯
# Let me get information about Spain's culture:
# Tool #4: http_request
# ╭──────────────────── 🚀 HTTP Request Preview: GET /api/rest_v1/page/summary/Culture_of_Spain ────────────────────╮
# │                                                                                                                 │
# │   Method    GET                                                                                                 │
# │   URL       https://en.wikipedia.org/api/rest_v1/page/summary/Culture_of_Spain                                  │
# │   Headers   {'User-Agent': 'ResearchAssistantBot/1.0'}                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Sending request...
# ╭─────────────────────────────────────────── ✅ HTTP Response: 200 OK ────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │     Status         200 OK                                                                                       │
# │     URL            https://en.wikipedia.org/api/rest_v1/page/summary/Culture_of_Spain                           │
# │     Content-Type   application/json; charset=utf-8;                                                             │
# │                    profile="https://www.mediawiki.org/wiki/Specs/Summary/1.5.0"                                 │
# │     Size           2,082 bytes (2.0 KB)                                                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                                  Response Headers
# ╭───────────────────────────────┬─────────────────────────────────────────────────────────────────────────────────╮
# │ Header                        │ Value                                                                           │
# ├───────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────┤
# │ content-security-policy       │ default-src 'none'; frame-ancestors 'none'                                      │
# │ x-content-security-policy     │ default-src 'none'; frame-ancestors 'none'                                      │
# │ x-webkit-csp                  │ default-src 'none'; frame-ancestors 'none'                                      │
# │ cache-control                 │ s-maxage=1209600, max-age=300                                                   │
# │ content-language              │ en                                                                              │
# │ content-type                  │ application/json; charset=utf-8;                                                │
# │                               │ profile="https://www.mediawiki.org/wiki/Specs/Summary/1.5.0"                    │
# │ date                          │ Sat, 29 Nov 2025 16:25:46 GMT                                                   │
# │ server                        │ production-tls                                                                  │
# │ access-control-allow-origin   │ *                                                                               │
# │ access-control-allow-methods  │ GET,HEAD                                                                        │
# │ access-control-allow-headers  │ accept, content-type, content-length, cache-control, accept-language,           │
# │                               │ api-user-agent, if-match, if-m...                                               │
# │ access-control-expose-headers │ etag                                                                            │
# │ x-content-type-options        │ nosniff                                                                         │
# │ x-frame-options               │ SAMEORIGIN                                                                      │
# │ referrer-policy               │ origin-when-cross-origin                                                        │
# │ x-xss-protection              │ 1; mode=block                                                                   │
# │ etag                          │ W/"1318754170/c2b372d0-cce6-11f0-84d7-688e52d458a0"                             │
# │ content-encoding              │ gzip                                                                            │
# │ age                           │ 1                                                                               │
# │ accept-ranges                 │ bytes                                                                           │
# │ vary                          │ Accept-Language, x-restbase-compat, Accept-Encoding                             │
# │ x-cache                       │ cp4041 miss, cp4041 miss                                                        │
# │ x-cache-status                │ miss                                                                            │
# │ server-timing                 │ cache;desc="miss", host;desc="cp4041"                                           │
# │ strict-transport-security     │ max-age=106384710; includeSubDomains; preload                                   │
# │ report-to                     │ { "group": "wm_nel", "max_age": 604800, "endpoints": [{ "url":                  │
# │                               │ "https://intake-logging.wikimedia.org...                                        │
# │ nel                           │ { "report_to": "wm_nel", "max_age": 604800, "failure_fraction": 0.05,           │
# │                               │ "success_fraction": 0.0}                                                        │
# │ x-client-ip                   │ 54.203.17.143                                                                   │
# │ transfer-encoding             │ chunked                                                                         │
# │ x-request-id                  │ 629e52b2-b89b-4b7a-824f-6378f335aabf                                            │
# │ x-analytics                   │                                                                                 │
# ╰───────────────────────────────┴─────────────────────────────────────────────────────────────────────────────────╯
# Let me gather information about Spain's economy:
# Tool #5: http_request
# ╭──────────────────── 🚀 HTTP Request Preview: GET /api/rest_v1/page/summary/Economy_of_Spain ────────────────────╮
# │                                                                                                                 │
# │   Method    GET                                                                                                 │
# │   URL       https://en.wikipedia.org/api/rest_v1/page/summary/Economy_of_Spain                                  │
# │   Headers   {'User-Agent': 'ResearchAssistantBot/1.0'}                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Sending request...
# ╭─────────────────────────────────────────── ✅ HTTP Response: 200 OK ────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │     Status         200 OK                                                                                       │
# │     URL            https://en.wikipedia.org/api/rest_v1/page/summary/Economy_of_Spain                           │
# │     Content-Type   application/json; charset=utf-8;                                                             │
# │                    profile="https://www.mediawiki.org/wiki/Specs/Summary/1.5.0"                                 │
# │     Size           3,109 bytes (3.0 KB)                                                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                                  Response Headers
# ╭───────────────────────────────┬─────────────────────────────────────────────────────────────────────────────────╮
# │ Header                        │ Value                                                                           │
# ├───────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────┤
# │ content-security-policy       │ default-src 'none'; frame-ancestors 'none'                                      │
# │ x-content-security-policy     │ default-src 'none'; frame-ancestors 'none'                                      │
# │ x-webkit-csp                  │ default-src 'none'; frame-ancestors 'none'                                      │
# │ cache-control                 │ s-maxage=1209600, max-age=300                                                   │
# │ content-language              │ en                                                                              │
# │ content-type                  │ application/json; charset=utf-8;                                                │
# │                               │ profile="https://www.mediawiki.org/wiki/Specs/Summary/1.5.0"                    │
# │ date                          │ Sat, 29 Nov 2025 16:25:48 GMT                                                   │
# │ server                        │ production-tls                                                                  │
# │ access-control-allow-origin   │ *                                                                               │
# │ access-control-allow-methods  │ GET,HEAD                                                                        │
# │ access-control-allow-headers  │ accept, content-type, content-length, cache-control, accept-language,           │
# │                               │ api-user-agent, if-match, if-m...                                               │
# │ access-control-expose-headers │ etag                                                                            │
# │ x-content-type-options        │ nosniff                                                                         │
# │ x-frame-options               │ SAMEORIGIN                                                                      │
# │ referrer-policy               │ origin-when-cross-origin                                                        │
# │ x-xss-protection              │ 1; mode=block                                                                   │
# │ etag                          │ W/"1323891416/9f1af0e0-cce7-11f0-996c-bc69316dddd3"                             │
# │ content-encoding              │ gzip                                                                            │
# │ age                           │ 0                                                                               │
# │ accept-ranges                 │ bytes                                                                           │
# │ vary                          │ Accept-Language, x-restbase-compat, Accept-Encoding                             │
# │ x-cache                       │ cp4041 miss, cp4041 miss                                                        │
# │ x-cache-status                │ miss                                                                            │
# │ server-timing                 │ cache;desc="miss", host;desc="cp4041"                                           │
# │ strict-transport-security     │ max-age=106384710; includeSubDomains; preload                                   │
# │ report-to                     │ { "group": "wm_nel", "max_age": 604800, "endpoints": [{ "url":                  │
# │                               │ "https://intake-logging.wikimedia.org...                                        │
# │ nel                           │ { "report_to": "wm_nel", "max_age": 604800, "failure_fraction": 0.05,           │
# │                               │ "success_fraction": 0.0}                                                        │
# │ x-client-ip                   │ 54.203.17.143                                                                   │
# │ transfer-encoding             │ chunked                                                                         │
# │ x-request-id                  │ 5a633371-0fc6-4573-a15a-bfc3c9e677f1                                            │
# │ x-analytics                   │                                                                                 │
# ╰───────────────────────────────┴─────────────────────────────────────────────────────────────────────────────────╯
# Let me research Spain's geography in more detail:
# Tool #6: http_request
# ╭─────────────────── 🚀 HTTP Request Preview: GET /api/rest_v1/page/summary/Geography_of_Spain ───────────────────╮
# │                                                                                                                 │
# │   Method    GET                                                                                                 │
# │   URL       https://en.wikipedia.org/api/rest_v1/page/summary/Geography_of_Spain                                │
# │   Headers   {'User-Agent': 'ResearchAssistantBot/1.0'}                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Sending request...
# ╭─────────────────────────────────────────── ✅ HTTP Response: 200 OK ────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │     Status         200 OK                                                                                       │
# │     URL            https://en.wikipedia.org/api/rest_v1/page/summary/Geography_of_Spain                         │
# │     Content-Type   application/json; charset=utf-8;                                                             │
# │                    profile="https://www.mediawiki.org/wiki/Specs/Summary/1.5.0"                                 │
# │     Size           2,373 bytes (2.3 KB)                                                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                                  Response Headers
# ╭───────────────────────────────┬─────────────────────────────────────────────────────────────────────────────────╮
# │ Header                        │ Value                                                                           │
# ├───────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────┤
# │ content-security-policy       │ default-src 'none'; frame-ancestors 'none'                                      │
# │ x-content-security-policy     │ default-src 'none'; frame-ancestors 'none'                                      │
# │ x-webkit-csp                  │ default-src 'none'; frame-ancestors 'none'                                      │
# │ cache-control                 │ s-maxage=1209600, max-age=300                                                   │
# │ content-language              │ en                                                                              │
# │ content-type                  │ application/json; charset=utf-8;                                                │
# │                               │ profile="https://www.mediawiki.org/wiki/Specs/Summary/1.5.0"                    │
# │ date                          │ Sat, 29 Nov 2025 16:25:50 GMT                                                   │
# │ server                        │ production-tls                                                                  │
# │ access-control-allow-origin   │ *                                                                               │
# │ access-control-allow-methods  │ GET,HEAD                                                                        │
# │ access-control-allow-headers  │ accept, content-type, content-length, cache-control, accept-language,           │
# │                               │ api-user-agent, if-match, if-m...                                               │
# │ access-control-expose-headers │ etag                                                                            │
# │ x-content-type-options        │ nosniff                                                                         │
# │ x-frame-options               │ SAMEORIGIN                                                                      │
# │ referrer-policy               │ origin-when-cross-origin                                                        │
# │ x-xss-protection              │ 1; mode=block                                                                   │
# │ etag                          │ W/"1314032261/3b764110-cce8-11f0-b986-18000c79e326"                             │
# │ content-encoding              │ gzip                                                                            │
# │ age                           │ 0                                                                               │
# │ accept-ranges                 │ bytes                                                                           │
# │ vary                          │ Accept-Language, x-restbase-compat, Accept-Encoding                             │
# │ x-cache                       │ cp4041 miss, cp4041 miss                                                        │
# │ x-cache-status                │ miss                                                                            │
# │ server-timing                 │ cache;desc="miss", host;desc="cp4041"                                           │
# │ strict-transport-security     │ max-age=106384710; includeSubDomains; preload                                   │
# │ report-to                     │ { "group": "wm_nel", "max_age": 604800, "endpoints": [{ "url":                  │
# │                               │ "https://intake-logging.wikimedia.org...                                        │
# │ nel                           │ { "report_to": "wm_nel", "max_age": 604800, "failure_fraction": 0.05,           │
# │                               │ "success_fraction": 0.0}                                                        │
# │ x-client-ip                   │ 54.203.17.143                                                                   │
# │ transfer-encoding             │ chunked                                                                         │
# │ x-request-id                  │ 5fe684e7-1e53-475a-b423-6a57f3c1070b                                            │
# │ x-analytics                   │                                                                                 │
# ╰───────────────────────────────┴─────────────────────────────────────────────────────────────────────────────────╯
# Finally, let me get information about Spain's major attractions:
# Tool #7: http_request
# ╭──────────────────── 🚀 HTTP Request Preview: GET /api/rest_v1/page/summary/Tourism_in_Spain ────────────────────╮
# │                                                                                                                 │
# │   Method    GET                                                                                                 │
# │   URL       https://en.wikipedia.org/api/rest_v1/page/summary/Tourism_in_Spain                                  │
# │   Headers   {'User-Agent': 'ResearchAssistantBot/1.0'}                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Sending request...
# ╭─────────────────────────────────────────── ✅ HTTP Response: 200 OK ────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                                                                                 │
# │     Status         200 OK                                                                                       │
# │     URL            https://en.wikipedia.org/api/rest_v1/page/summary/Tourism_in_Spain                           │
# │     Content-Type   application/json; charset=utf-8;                                                             │
# │                    profile="https://www.mediawiki.org/wiki/Specs/Summary/1.5.0"                                 │
# │     Size           2,807 bytes (2.7 KB)                                                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                                  Response Headers
# ╭───────────────────────────────┬─────────────────────────────────────────────────────────────────────────────────╮
# │ Header                        │ Value                                                                           │
# ├───────────────────────────────┼─────────────────────────────────────────────────────────────────────────────────┤
# │ content-security-policy       │ default-src 'none'; frame-ancestors 'none'                                      │
# │ x-content-security-policy     │ default-src 'none'; frame-ancestors 'none'                                      │
# │ x-webkit-csp                  │ default-src 'none'; frame-ancestors 'none'                                      │
# │ cache-control                 │ s-maxage=1209600, max-age=300                                                   │
# │ content-language              │ en                                                                              │
# │ content-type                  │ application/json; charset=utf-8;                                                │
# │                               │ profile="https://www.mediawiki.org/wiki/Specs/Summary/1.5.0"                    │
# │ date                          │ Sat, 29 Nov 2025 16:25:53 GMT                                                   │
# │ server                        │ production-tls                                                                  │
# │ access-control-allow-origin   │ *                                                                               │
# │ access-control-allow-methods  │ GET,HEAD                                                                        │
# │ access-control-allow-headers  │ accept, content-type, content-length, cache-control, accept-language,           │
# │                               │ api-user-agent, if-match, if-m...                                               │
# │ access-control-expose-headers │ etag                                                                            │
# │ x-content-type-options        │ nosniff                                                                         │
# │ x-frame-options               │ SAMEORIGIN                                                                      │
# │ referrer-policy               │ origin-when-cross-origin                                                        │
# │ x-xss-protection              │ 1; mode=block                                                                   │
# │ etag                          │ W/"1324333026/7c6f2370-cce9-11f0-9b43-98b416a823f8"                             │
# │ content-encoding              │ gzip                                                                            │
# │ age                           │ 0                                                                               │
# │ accept-ranges                 │ bytes                                                                           │
# │ vary                          │ Accept-Language, x-restbase-compat, Accept-Encoding                             │
# │ x-cache                       │ cp4041 miss, cp4041 miss                                                        │
# │ x-cache-status                │ miss                                                                            │
# │ server-timing                 │ cache;desc="miss", host;desc="cp4041"                                           │
# │ strict-transport-security     │ max-age=106384710; includeSubDomains; preload                                   │
# │ report-to                     │ { "group": "wm_nel", "max_age": 604800, "endpoints": [{ "url":                  │
# │                               │ "https://intake-logging.wikimedia.org...                                        │
# │ nel                           │ { "report_to": "wm_nel", "max_age": 604800, "failure_fraction": 0.05,           │
# │                               │ "success_fraction": 0.0}                                                        │
# │ x-client-ip                   │ 54.203.17.143                                                                   │
# │ transfer-encoding             │ chunked                                                                         │
# │ x-request-id                  │ dcb666d3-8798-461d-9f0e-4a634a04a71b                                            │
# │ x-analytics                   │                                                                                 │
# ╰───────────────────────────────┴─────────────────────────────────────────────────────────────────────────────────╯
# # Spain: A Comprehensive Overview
#
# Based on the information gathered, here's a detailed overview of Spain covering its history, culture, geography, economy, and major attractions:
#
# ## General Overview
# Spain, officially the Kingdom of Spain, is a country located in Southern and Western Europe with territories in North Africa. It is the largest country in Southern Europe and the fourth-most populous European Union member state. Spain's capital and largest city is Madrid, with other major urban areas including Barcelona, Valencia, Seville, Zaragoza, Málaga, Murcia, and Palma de Mallorca.
#
# ## History
# The history of Spain dates back to pre-Roman times when the Mediterranean coast of the Iberian Peninsula had contact with Greeks and Phoenicians. During Classical Antiquity, the peninsula experienced successive colonizations by Greeks, Carthaginians, and Romans. Native peoples of the peninsula, such as the Tartessos, intermingled with these colonizers to create a uniquely Iberian culture.
#
# The Romans referred to the entire peninsula as Hispania, from which the modern name "Spain" originates. Following the decline of the Western Roman Empire, Spain experienced invasions by Germanic tribes during the 4th and 5th centuries AD, leading to the establishment of Germanic kingdoms and marking the beginning of the Middle Ages in Spain.
#
# ## Culture
# Spanish culture is shaped by its Western heritage, interactions with other European cultures, its historically Catholic religious tradition, and diverse national and regional identities within the country. Spanish culture encompasses:
#
# - Literature, music, and visual arts
# - Distinctive cuisine
# - Customs, beliefs, institutions, and social norms
#
# Beyond Spain's borders, Spanish culture forms a major component of most Latin American cultures and has been an important influence on Filipino culture, reflecting Spain's colonial history.
#
# ## Geography
# Spain occupies most of the Iberian Peninsula in southwestern Europe. Its territory also includes:
#
# - The Balearic Islands in the Mediterranean
# - The Canary Islands in the Atlantic Ocean (108 km off northwest Africa)
# - A small exclave inside France called Llívia
# - Five places of sovereignty on and off the coast of North Africa: Ceuta, Melilla, Islas Chafarinas, Peñón de Alhucemas, and Peñón de Vélez de la Gomera
#
# Peninsular Spain is bordered to the north by France, Andorra, and the Bay of Biscay; to the east and south by the Mediterranean Sea and Gibraltar; and to the west by Portugal and the Atlantic Ocean. Spain features the southernmost point of continental Europe.
#
# ## Economy
# Spain has a highly developed social market economy, ranking as the world's 12th largest by nominal GDP and the sixth-largest in Europe. Key facts about Spain's economy include:
#
# - Member of the European Union, eurozone, OECD, and World Trade Organization
# - 17th-largest exporter and 17th-largest importer globally (as of 2024)
# - Ranked 28th in the UN Human Development Index and 30th in GDP per capita by the IMF
# - Major economic sectors: automotive industry, medical technology, chemicals, shipbuilding, tourism, and textiles
# - Strong social security system that comprises approximately 23% of GDP
#
# ## Tourism and Major Attractions
# Tourism is a vital sector of Spain's economy, contributing 12.3% to the country's GDP. International tourist expenditure reached approximately 126 billion euros in 2024. Since 1959, tourism has become one of the key sectors of the Spanish economy.
#
# Spain's foreign tourist industry is the second-largest in the world, attracting visitors primarily from the United Kingdom, Ireland, France, Germany, Italy, the Benelux countries, and the United States. The country is especially popular for summer holidays.
#
# Major attractions include:
# - The Alhambra palace complex in Granada
# - Antoni Gaudí's architectural works in Barcelona, including Sagrada Familia
# - The Prado Museum in Madrid
# - Historic cities like Toledo, Seville, and Córdoba
# - Beach destinations along the Mediterranean coast and Canary Islands
# - The Camino de Santiago pilgrimage route
#
# ## Sources:
# 1. Wikipedia: Spain - https://en.wikipedia.org/wiki/Spain
# 2. Wikipedia: History of Spain - https://en.wikipedia.org/wiki/History_of_Spain
# ...
#
# ---
#
# ## Day 3: Barcelona to Madrid
# **Morning**
# - Breakfast (~$8)
# - Visit Park Güell (tickets ~$12)
# - Check out of hotel
#
# **Afternoon**
# - High-speed train to Madrid (~$70-90, 2.5 hours)
# - Check into Madrid hotel
# - Late lunch in Madrid (~$18)
# - Visit Plaza Mayor and surrounding historic center
#
# **Evening**
# - Tapas crawl in La Latina district (~$30 for various tapas and drinks)
#
# **Accommodations**: Mid-range hotel in Madrid (~$110-170/night)
#
# ---
#
# ## Day 4: Madrid - Culture & Art
# **Morning**
# - Breakfast (~$8)
# - Visit the Prado Museum (tickets ~$15)
# - See works by Goya, Velázquez, and El Greco
#
# **Afternoon**
# - Lunch near Retiro Park (~$18)
# - Stroll through El Retiro Park, Madrid's green oasis
# - Visit the Crystal Palace and row a boat on the lake (~$8)
#
# **Evening**
# - Dinner in the Salamanca district (~$35)
# - Optional: Cocktail at a rooftop bar (~$15)
#
# ---
#
# ## Day 5: Madrid to Seville
# **Morning**
# - Breakfast (~$8)
# - Visit Royal Palace of Madrid (~$15)
# - Check out of hotel
#
# **Afternoon**
# - High-speed train to Seville (~$60-80, 2.5 hours)
# - Check into Seville hotel
# - Late lunch in Seville (~$18)
# - Visit Plaza de España and María Luisa Park
#
# **Evening**
# - Dinner in the Santa Cruz neighborhood (~$30)
# - Evening walk along the Guadalquivir River
#
# **Accommodations**: Mid-range hotel in Seville (~$100-160/night)
#
# ---
#
# ## Day 6: Seville - Andalusian Splendor
# **Morning**
# - Breakfast (~$8)
# - Visit the Royal Alcázar (tickets ~$15)
# - Explore the stunning Mudéjar architecture and gardens
#
# **Afternoon**
# - Lunch in the Jewish Quarter (~$20)
# - Visit Seville Cathedral and climb La Giralda tower (~$12)
# - Explore the charming streets of Barrio Santa Cruz
#
# **Evening**
# - Authentic flamenco show with dinner (~$45-60)
#
# ---
#
# ## Day 7: Departure Day
# **Morning**
# - Breakfast (~$8)
# - Final sightseeing or shopping for souvenirs
# - Visit Metropol Parasol "Las Setas" (~$5)
#
# **Afternoon**
# - Late checkout
# - Transfer to Seville Airport
# - Departure flight
#
# ---
#
# ## Budget Breakdown (per person):
#
# **Flights:**
# - International round-trip flight to/from Spain: $600-900 (varies by origin)
#
# **Accommodations (6 nights):**
# - Barcelona (2 nights): $240-360
# - Madrid (2 nights): $220-340
# - Seville (2 nights): $200-320
# - **Total Accommodations:** $660-1,020
#
# **Transportation:**
# - Airport transfers (all cities): $60-80
# - Barcelona to Madrid train: $70-90
# - Madrid to Seville train: $60-80
# - Public transportation in cities: $40-50
# - **Total Transportation:** $230-300
#
# **Food:**
# - Breakfasts (7): $56
# - Lunches (7): $115-140
# - Dinners (6): $175-215
# - **Total Food:** $345-410
#
# **Attractions and Activities:**
# - Barcelona sights: $95-105
# - Madrid sights: $40-50
# - Seville sights: $35-45
# - Flamenco shows: $35-95
# - **Total Activities:** $205-295
#
# **Miscellaneous:**
# - Travel insurance: $30-50
# - Souvenirs/shopping: $50-100 (optional)
# - **Total Miscellaneous:** $80-150
#
# ---
#
# ### Money-Saving Tips:
# 1. Consider a tourist pass in each city for attractions
# 2. Book train tickets in advance for better rates
# 3. Have larger meals at lunch when "menú del día" specials are available
# 4. Stay in accommodations with breakfast included
# 5. Use public transportation rather than taxis
#
# ### Notes:
# - This itinerary is moderately paced but includes major highlights
# - Prices are estimated in USD and may vary by season
# - Summer months are more expensive; spring and fall offer better value
# - Add 1-2 more days if you prefer a more relaxed pace
#
# Would you like me to adjust any part of this itinerary to better match your preferences?Here's a combined response with the research on Spain and your 7-day trip plan. Would you like me to save this information to a file for you?
#
# # Spain: Research and 7-Day Trip Plan
#
# ## Part 1: Spain Overview
#
# ### General Overview
# Spain, officially the Kingdom of Spain, is a country located in Southern and Western Europe with territories in North Africa. It is the largest country in Southern Europe and the fourth-most populous European Union member state. Spain's capital and largest city is Madrid, with other major urban areas including Barcelona, Valencia, Seville, Zaragoza, Málaga, Murcia, and Palma de Mallorca.
#
# ### History
# The history of Spain dates back to pre-Roman times when the Mediterranean coast of the Iberian Peninsula had contact with Greeks and Phoenicians. During Classical Antiquity, the peninsula experienced successive colonizations by Greeks, Carthaginians, and Romans. Native peoples of the peninsula, such as the Tartessos, intermingled with these colonizers to create a uniquely Iberian culture.
#
# The Romans referred to the entire peninsula as Hispania, from which the modern name "Spain" originates. Following the decline of the Western Roman Empire, Spain experienced invasions by Germanic tribes during the 4th and 5th centuries AD, leading to the establishment of Germanic kingdoms and marking the beginning of the Middle Ages in Spain.
#
# ### Culture
# Spanish culture is shaped by its Western heritage, interactions with other European cultures, its historically Catholic religious tradition, and diverse national and regional identities within the country. Spanish culture encompasses:
#
# - Literature, music, and visual arts
# - Distinctive cuisine
# - Customs, beliefs, institutions, and social norms
#
# Beyond Spain's borders, Spanish culture forms a major component of most Latin American cultures and has been an important influence on Filipino culture, reflecting Spain's colonial history.
#
# ### Geography
# Spain occupies most of the Iberian Peninsula in southwestern Europe. Its territory also includes:
#
# - The Balearic Islands in the Mediterranean
# - The Canary Islands in the Atlantic Ocean (108 km off northwest Africa)
# - A small exclave inside France called Llívia
# - Five places of sovereignty on and off the coast of North Africa: Ceuta, Melilla, Islas Chafarinas, Peñón de Alhucemas, and Peñón de Vélez de la Gomera
#
# Peninsular Spain is bordered to the north by France, Andorra, and the Bay of Biscay; to the east and south by the Mediterranean Sea and Gibraltar; and to the west by Portugal and the Atlantic Ocean. Spain features the southernmost point of continental Europe.
#
# ### Economy
# Spain has a highly developed social market economy, ranking as the world's 12th largest by nominal GDP and the sixth-largest in Europe. Key facts about Spain's economy include:
#
# - Member of the European Union, eurozone, OECD, and World Trade Organization
# - 17th-largest exporter and 17th-largest importer globally (as of 2024)
# - Ranked 28th in the UN Human Development Index and 30th in GDP per capita by the IMF
# - Major economic sectors: automotive industry, medical technology, chemicals, shipbuilding, tourism, and textiles
# - Strong social security system that comprises approximately 23% of GDP
#
# ### Tourism and Major Attractions
# Tourism is a vital sector of Spain's economy, contributing 12.3% to the country's GDP. International tourist expenditure reached approximately 126 billion euros in 2024. Since 1959, tourism has become one of the key sectors of the Spanish economy.
#
# Major attractions include:
# - The Alhambra palace complex in Granada
# - Antoni Gaudí's architectural works in Barcelona, including Sagrada Familia
# - The Prado Museum in Madrid
# - Historic cities like Toledo, Seville, and Córdoba
# - Beach destinations along the Mediterranean coast and Canary Islands
# - The Camino de Santiago pilgrimage route
#
# ## Part 2: 7-Day Spain Itinerary
#
# ### Overview
# This 7-day itinerary covers Spain's three most iconic cities: Barcelona, Madrid, and Seville, highlighting major attractions while providing cultural experiences and local cuisine.
#
# ### Estimated Total Cost: $2,100-$2,800 per person
# *(Based on mid-range budget; costs can vary by season and preferences)*
#
# ---
#
# ### Day 1: Arrive in Barcelona
# **Morning**
# - Arrival at Barcelona-El Prat Airport
# - Check-in at hotel in central Barcelona
# - Light lunch at a café near La Rambla (~$15)
#
# **Afternoon**
# - Stroll down La Rambla, Barcelona's famous pedestrian boulevard
# - Visit La Boqueria Market to sample local treats (~$10)
# - Explore the Gothic Quarter's narrow medieval streets
#
# **Evening**
# - Dinner at a traditional Catalan restaurant (~$25-35)
# - Evening paseo (stroll) along the waterfront
#
# **Accommodations**: Mid-range hotel in Barcelona (~$120-180/night)
#
# ---
#
# ### Day 2: Barcelona - Gaudí Day
# **Morning**
# - Breakfast at hotel or local café (~$8)
# - Visit Sagrada Família (pre-book tickets: ~$26)
# - Explore the architectural marvel inside and out (2-3 hours)
#
# **Afternoon**
# - Lunch near Passeig de Gràcia (~$18)
# - Visit Casa Batlló (~$30) and Casa Milà/La Pedrera (~$25)
# - Stroll through the elegant Eixample district
#
# **Evening**
# - Dinner in the El Born district (~$30)
# - Optional: Flamenco show (~$35)
#
# ---
#
# ### Day 3: Barcelona to Madrid
# **Morning**
# - Breakfast (~$8)
# - Visit Park Güell (tickets ~$12)
# - Check out of hotel
#
# **Afternoon**
# - High-speed train to Madrid (~$70-90, 2.5 hours)
# - Check into Madrid hotel
# - Late lunch in Madrid (~$18)
# - Visit Plaza Mayor and surrounding historic center
#
# **Evening**
# - Tapas crawl in La Latina district (~$30 for various tapas and drinks)
#
# **Accommodations**: Mid-range hotel in Madrid (~$110-170/night)
#
# ---
#
# ### Day 4: Madrid - Culture & Art
# **Morning**
# - Breakfast (~$8)
# - Visit the Prado Museum (tickets ~$15)
# - See works by Goya, Velázquez, and El Greco
#
# **Afternoon**
# - Lunch near Retiro Park (~$18)
# - Stroll through El Retiro Park, Madrid's green oasis
# - Visit the Crystal Palace and row a boat on the lake (~$8)
#
# **Evening**
# - Dinner in the Salamanca district (~$35)
# - Optional: Cocktail at a rooftop bar (~$15)
#
# ---
#
# ### Day 5: Madrid to Seville
# **Morning**
# - Breakfast (~$8)
# - Visit Royal Palace of Madrid (~$15)
# - Check out of hotel
#
# **Afternoon**
# - High-speed train to Seville (~$60-80, 2.5 hours)
# - Check into Seville hotel
# - Late lunch in Seville (~$18)
# - Visit Plaza de España and María Luisa Park
#
# **Evening**
# - Dinner in the Santa Cruz neighborhood (~$30)
# - Evening walk along the Guadalquivir River
#
# **Accommodations**: Mid-range hotel in Seville (~$100-160/night)
#
# ---
#
# ### Day 6: Seville - Andalusian Splendor
# **Morning**
# - Breakfast (~$8)
# - Visit the Royal Alcázar (tickets ~$15)
# - Explore the stunning Mudéjar architecture and gardens
#
# **Afternoon**
# - Lunch in the Jewish Quarter (~$20)
# - Visit Seville Cathedral and climb La Giralda tower (~$12)
# - Explore the charming streets of Barrio Santa Cruz
#
# **Evening**
# - Authentic flamenco show with dinner (~$45-60)
#
# ---
#
# ### Day 7: Departure Day
# **Morning**
# - Breakfast (~$8)
# - Final sightseeing or shopping for souvenirs
# - Visit Metropol Parasol "Las Setas" (~$5)
#
# **Afternoon**
# - Late checkout
# - Transfer to Seville Airport
# - Departure flight
#
# ---
#
# ## Budget Breakdown (per person):
#
# **Flights:**
# - International round-trip flight to/from Spain: $600-900 (varies by origin)
#
# **Accommodations (6 nights):**
# - Barcelona (2 nights): $240-360
# - Madrid (2 nights): $220-340
# - Seville (2 nights): $200-320
# - **Total Accommodations:** $660-1,020
#
# **Transportation:**
# - Airport transfers (all cities): $60-80
# - Barcelona to Madrid train: $70-90
# - Madrid to Seville train: $60-80
# - Public transportation in cities: $40-50
# - **Total Transportation:** $230-300
#
# **Food:**
# - Breakfasts (7): $56
# - Lunches (7): $115-140
# - Dinners (6): $175-215
# - **Total Food:** $345-410
#
# **Attractions and Activities:**
# - Barcelona sights: $95-105
# - Madrid sights: $40-50
# - Seville sights: $35-45
# - Flamenco shows: $35-95
# - **Total Activities:** $205-295
#
# **Miscellaneous:**
# - Travel insurance: $30-50
# - Souvenirs/shopping: $50-100 (optional)
# - **Total Miscellaneous:** $80-150
#
# ### Money-Saving Tips:
# 1. Consider a tourist pass in each city for attractions
# 2. Book train tickets in advance for better rates
# 3. Have larger meals at lunch when "menú del día" specials are available
# 4. Stay in accommodations with breakfast included
# 5. Use public transportation rather than taxis
#
# Would you like me to save this information to a file for you? Or is there any part of the itinerary you'd like to modify?
# AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'Here\'s a combined response with the research on Spain and your 7-day trip plan. Would you like me to save this information to a file for you?\n\n# Spain: Research and 7-Day Trip Plan\n\n## Part 1: Spain Overview\n\n### General Overview\nSpain, officially the Kingdom of Spain, is a country located in Southern and Western Europe with territories in North Africa. It is the largest country in Southern Europe and the fourth-most populous European Union member state. Spain\'s capital and largest city is Madrid, with other major urban areas including Barcelona, Valencia, Seville, Zaragoza, Málaga, Murcia, and Palma de Mallorca.\n\n### History\nThe history of Spain dates back to pre-Roman times when the Mediterranean coast of the Iberian Peninsula had contact with Greeks and Phoenicians. During Classical Antiquity, the peninsula experienced successive colonizations by Greeks, Carthaginians, and Romans. Native peoples of the peninsula, such as the Tartessos, intermingled with these colonizers to create a uniquely Iberian culture.\n\nThe Romans referred to the entire peninsula as Hispania, from which the modern name "Spain" originates. Following the decline of the Western Roman Empire, Spain experienced invasions by Germanic tribes during the 4th and 5th centuries AD, leading to the establishment of Germanic kingdoms and marking the beginning of the Middle Ages in Spain.\n\n### Culture\nSpanish culture is shaped by its Western heritage, interactions with other European cultures, its historically Catholic religious tradition, and diverse national and regional identities within the country. Spanish culture encompasses:\n\n- Literature, music, and visual arts\n- Distinctive cuisine\n- Customs, beliefs, institutions, and social norms\n\nBeyond Spain\'s borders, Spanish culture forms a major component of most Latin American cultures and has been an important influence on Filipino culture, reflecting Spain\'s colonial history.\n\n### Geography\nSpain occupies most of the Iberian Peninsula in southwestern Europe. Its territory also includes:\n\n- The Balearic Islands in the Mediterranean\n- The Canary Islands in the Atlantic Ocean (108 km off northwest Africa)\n- A small exclave inside France called Llívia\n- Five places of sovereignty on and off the coast of North Africa: Ceuta, Melilla, Islas Chafarinas, Peñón de Alhucemas, and Peñón de Vélez de la Gomera\n\nPeninsular Spain is bordered to the north by France, Andorra, and the Bay of Biscay; to the east and south by the Mediterranean Sea and Gibraltar; and to the west by Portugal and the Atlantic Ocean. Spain features the southernmost point of continental Europe.\n\n### Economy\nSpain has a highly developed social market economy, ranking as the world\'s 12th largest by nominal GDP and the sixth-largest in Europe. Key facts about Spain\'s economy include:\n\n- Member of the European Union, eurozone, OECD, and World Trade Organization\n- 17th-largest exporter and 17th-largest importer globally (as of 2024)\n- Ranked 28th in the UN Human Development Index and 30th in GDP per capita by the IMF\n- Major economic sectors: automotive industry, medical technology, chemicals, shipbuilding, tourism, and textiles\n- Strong social security system that comprises approximately 23% of GDP\n\n### Tourism and Major Attractions\nTourism is a vital sector of Spain\'s economy, contributing 12.3% to the country\'s GDP. International tourist expenditure reached approximately 126 billion euros in 2024. Since 1959, tourism has become one of the key sectors of the Spanish economy.\n\nMajor attractions include:\n- The Alhambra palace complex in Granada\n- Antoni Gaudí\'s architectural works in Barcelona, including Sagrada Familia\n- The Prado Museum in Madrid\n- Historic cities like Toledo, Seville, and Córdoba\n- Beach destinations along the Mediterranean coast and Canary Islands\n- The Camino de Santiago pilgrimage route\n\n##  ...

# %% [markdown]
# Behind the scenes, the orchestrator will:
# 1. First call the `research_assistant`
# 2. Then call `trip_planning_assistant`
# 3. Combine these specialized responses into a cohesive answer that addresses both the queries

# %% [markdown]
# ### Sequential Agent Communication Pattern

# %% [markdown]
# The agent tool can also combine multiple agents together. In this example we will provide output of `research_agent` to `summary_agent` and return the summarized response.

# %%
 # define the user query
topic = "generative Ai"
# Create a research agent
research_agent = Agent(
    model="us.anthropic.claude-3-7-sonnet-20250219-v1:0",
    system_prompt=RESEARCH_ASSISTANT_PROMPT,
)
# Create a summarization agent
summary_agent = Agent(
    model="us.anthropic.claude-3-7-sonnet-20250219-v1:0",
    system_prompt="""
    You are a summarization specialist focused on distilling complex information into clear, concise summaries.
    Your primary goal is to take detailed information and extract the key points, main arguments, and critical data.
    You should maintain the accuracy of the original content while making it more digestible.
    Focus on clarity, brevity, and highlighting the most important aspects of the information.
    """,
)

print("Multiple agents created successfully!")
print(f"\n🔍 RESEARCH AGENT working on: {topic}\n") 
try:
    # Agent 1: Invoke research agent
    research_response = research_agent(
        f"Please gather comprehensive information about {topic}."
    )
    research_text = research_response.message.content[0]["text"]
    print("\n✂️ SUMMARY AGENT distilling the research\n")
    
    # Agent 2: Ask the summary agent to create a concise summary
    summary_response = summary_agent(
        f"Please create a concise summary of this research: {research_text}"
    )
    summary_text = summary_response.message.content[0]["text"]
    
    print(summary_text)
except Exception as e:
    print(f"Error in research assistant: {str(e)}")
# Out:
# Multiple agents created successfully!
#
# 🔍 RESEARCH AGENT working on: generative Ai
#
# # Generative AI: A Comprehensive Overview
#
# Generative AI refers to artificial intelligence systems that can create new content including text, images, audio, video, code, and synthetic data.
#
# ## Core Technologies and Methods
#
# **Foundation Models**: Large-scale neural networks trained on vast datasets that serve as the basis for various generative applications.
#
# - **Transformer Architecture**: The dominant neural network architecture powering most modern generative AI systems, introduced in the paper "Attention Is All You Need" (Vaswani et al., 2017)[1].
#
# - **Training Approaches**: Most systems use self-supervised learning, where the model learns patterns from unlabeled data, often predicting masked or future elements[2].
#
# ## Major Categories of Generative AI
#
# 1. **Large Language Models (LLMs)**
#    - Examples: GPT-4 (OpenAI), Claude (Anthropic), Llama (Meta), PaLM/Gemini (Google)
#    - Capabilities: Text generation, translation, summarization, question-answering, and reasoning[3]
#
# 2. **Image Generation Models**
#    - Examples: DALL-E, Stable Diffusion, Midjourney
#    - Technologies: Diffusion models, GANs (Generative Adversarial Networks), VAEs (Variational Autoencoders)[4]
#
# 3. **Audio/Music Generation**
#    - Examples: AudioLM, MusicLM, Jukebox
#    - Applications: Voice synthesis, music composition, sound effects[5]
#
# 4. **Video Generation**
#    - Examples: Sora (OpenAI), Lumiere (Google), Gen-2 (Runway)
#    - Still emerging but advancing rapidly[6]
#
# 5. **Code Generation**
#    - Examples: GitHub Copilot, CodeLlama
#    - Applications: Code completion, debugging, translation between languages[7]
#
# ## Technical Challenges
#
# - **Hallucinations**: Models can generate plausible but factually incorrect information[8]
# - **Bias**: Systems may reproduce or amplify biases present in training data[9]
# - **Computational Requirements**: Training and running advanced models requires significant computing resources[10]
# - **Context Window Limitations**: Many models have constraints on how much information they can process at once[11]
#
# ## Ethical and Societal Implications
#
# - **Copyright and Intellectual Property**: Questions about training on copyrighted works and ownership of generated content[12]
# - **Employment Impact**: Potential disruption to creative and knowledge work professions[13]
# - **Misinformation Concerns**: Ease of generating convincing fake content[14]
# - **Privacy Issues**: Models may memorize and potentially reproduce private information from training data[15]
#
# ## Current Commercial Applications
#
# - Content creation assistance (marketing, design)
# - Customer service automation
# - Software development assistance
# - Medical research and drug discovery
# - Education and personalized learning[16]
#
# ---
#
# Sources:
# [1] Vaswani et al. (2017). "Attention Is All You Need." NeurIPS.
# [2] Bommasani et al. (2021). "On the Opportunities and Risks of Foundation Models." Stanford HAI.
# [3] Brown et al. (2020). "Language Models are Few-Shot Learners." NeurIPS.
# [4] Ramesh et al. (2022). "Hierarchical Text-Conditional Image Generation with CLIP Latents." arXiv.
# [5] Agostinelli et al. (2023). "MusicLM: Generating Music From Text." arXiv.
# [6] OpenAI. (2024). "Sora: Creating video from text." OpenAI Blog.
# [7] Chen et al. (2021). "Evaluating Large Language Models Trained on Code." arXiv.
# [8] Ji et al. (2023). "Survey of Hallucination in Natural Language Generation." ACM Computing Surveys.
# [9] Bender et al. (2021). "On the Dangers of Stochastic Parrots." ACM FAccT.
# [10] Patterson et al. (2021). "Carbon Emissions and Large Neural Network Training." arXiv.
# [11] Beltagy et al. (2020). "Longformer: The Long-Document Transformer." arXiv.
# [12] Samuelson. (2023). "AI Challenges for Copyright Law." Communications of the ACM.
# [13] Acemoglu & Restrepo. (2022). "Tasks, Automation, and the Rise in US Wage Inequality." NBER.
# [14] Goldstein et al. (2023). "Generative Language Models and Automated Influence Operations." arXiv.
# [15] Carlini et al. (2021). "Extracting Training Data from Large Language Models." USENIX.
# [16] McKinsey. (2023). "The Economic Potential of Generative AI." McKinsey Global Institute.Error in research assistant: 'dict' object has no attribute 'content'

# %% [markdown]
# ## Congrats!
#
# You've learned how to use agents as tools in Strands Agents to create more complex agentic applications
